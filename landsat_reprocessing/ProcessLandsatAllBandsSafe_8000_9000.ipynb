# %%
# !pip install uv
# !uv pip install  -r requirements.txt

# %%
import time
# import snowflake
# from snowflake.snowpark.context import get_active_session
# session = get_active_session()

import warnings
warnings.filterwarnings("ignore")

# Data manipulation and analysis
import numpy as np
import pandas as pd

# Planetary Computer tools for STAC API access and authentication
import pystac_client
import planetary_computer as pc
from odc.stac import stac_load
from pystac.extensions.eo import EOExtension as eo

from datetime import date
from tqdm import tqdm
import os
import time

# %%
# Setup
tqdm.pandas()

catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=pc.sign_inplace,
    )

bands_of_interest = {'red', 'blue', 'drad', 'emis', 'emsd', 'lwir', 'trad', 'urad', 'atran', 'cdist', 'green', 'nir08', 'swir16', 'swir22', 'atmos_opacity'}

def compute_Landsat_values(row):
    lat = row['Latitude']
    lon = row['Longitude']
    date = pd.to_datetime(row['Sample Date'], dayfirst=True, errors='coerce')


    # Buffer size for ~100m 
    bbox_size = 0.00089831  
    bbox = [
        lon - bbox_size / 2,
        lat - bbox_size / 2,
        lon + bbox_size / 2,
        lat + bbox_size / 2
    ]

    # Wider search range, we'll filter to nearest date later
    search = catalog.search(
        collections=["landsat-c2-l2"],
        bbox=bbox,
        datetime="2011-01-01/2015-12-31",
        query={"eo:cloud_cover": {"lt": 10}},
    )
    
    items = search.item_collection()

    if not items:
        # return pd.Series({
        #     "nir": np.nan
        #     , "green": np.nan
        #     , "swir16": np.nan
        #     , "swir22": np.nan
        #     , "red": np.nan
        #     , "blue": np.nan
        # })
        print("No items found")
        return pd.Series([np.nan] * len(bands_of_interest), index=bands_of_interest)


    # Convert sample date to UTC
    sample_date_utc = date.tz_localize("UTC") if date.tzinfo is None else date.tz_convert("UTC")

    # Pick the item closest to the sample date
    items = sorted(
        items,
        key=lambda x: abs(pd.to_datetime(x.properties["datetime"]).tz_convert("UTC") - sample_date_utc)
    )
    selected_item = pc.sign(items[0])

    # max_key_length = len(max(selected_item.assets, key=len))
    # for key, asset in selected_item.assets.items():
    #     print(f"{key.rjust(max_key_length)}: {asset.title}")

    # Load required bands
    # bands_of_interest = ["green", "nir08", "swir16", "swir22", "red", "blue"]
    bands_to_extract = [band for band in bands_of_interest if band in selected_item.assets.keys()]
    data = stac_load([selected_item], bands=bands_to_extract, bbox=bbox).isel(time=0)


    medians = []
    for band_name in bands_of_interest:
        if band_name in selected_item.assets.keys():
            band = data[band_name].astype("float")
            # Compute medians
            median_band = float(band.median(skipna=True).values)
            # Replace 0 with NaN
            median_band = median_band if median_band != 0 else np.nan
            medians.append(median_band)
        else:
            medians.append(np.nan)
    # print(pd.Series(medians, index=bands_of_interest))
    return pd.Series(medians, index=bands_of_interest)

# %%
Water_Quality_df=pd.read_csv('../water_quality_training_dataset.csv')
display(Water_Quality_df.head())
# Out:
#     Latitude  Longitude Sample Date  Total Alkalinity  Electrical Conductance  \
# 0 -28.760833  17.730278  02-01-2011           128.912                   555.0
# 1 -26.861111  28.884722  03-01-2011            74.720                   162.9
# 2 -26.450000  28.085833  03-01-2011            89.254                   573.0
# 3 -27.671111  27.236944  03-01-2011            82.000                   203.6
# 4 -27.356667  27.286389  03-01-2011            56.100                   145.1
#
#    Dissolved Reactive Phosphorus
# 0                           10.0
# 1                          163.0
# 2                           80.0
# 3                          101.0
# 4                          151.0

# %%
start_index = 8000
end_index = 9000
start_end_index_diff = end_index - start_index
to_process_df = Water_Quality_df[start_index:end_index]
print(to_process_df.shape)
# Out:
# (1000, 6)

# %%
len_full_df = 0
count=0
file_path = f"all_bands_extraction/landsat_features_training_all_bands_{start_index}_{end_index}.csv"
full_df = None
while len_full_df < start_end_index_diff and count < 20:

    file_path = f"all_bands_extraction/landsat_features_training_all_bands_{start_index}_{end_index}.csv"
    full_df = None
    if os.path.isfile(file_path):
        full_df = pd.read_csv(file_path)

    len_to_process_df = to_process_df.shape[0]

    for index, row in to_process_df.iterrows():
        try:
            lon = row["Longitude"]
            lat = row["Latitude"]
            sample_date = row["Sample Date"]
            print(f"{index - start_index + 1}/{len_to_process_df} Processing\n\t- Lat: {lat}\n\t- Lon: {lon}\n\t- Sample Date: {sample_date}\n")

            if full_df is not None and index - start_index + 1 <= full_df.shape[0]:
                len_full_df = full_df.shape[0]
                print(f"\tSkipping... {index - start_index + 1} <= {full_df.shape[0]}")
                continue

            new_row = compute_Landsat_values(row)

            row_df = row.to_frame().T
            row_df = row_df[["Latitude", "Longitude", "Sample Date"]]
            new_row_df = new_row.to_frame().T

            row_df = row_df.reset_index(drop=True)
            new_row_df = new_row_df.reset_index(drop=True)
            new_row_df = pd.concat([row_df, new_row_df], axis=1)

            # print(new_row)
            if full_df is None:
                full_df = new_row_df
                print(full_df)
            else:
                full_df = full_df.reset_index(drop=True)
                full_df = pd.concat([full_df, new_row_df], axis=0, ignore_index=True)

            len_full_df = full_df.shape[0]

            print(f"len_full_df = {len_full_df}, count = {count}")
        except Exception as e:
            full_df.to_csv(file_path, index = False, mode='w')
            print(f"Failed !!!\n{e}")
            count+=1
            break

full_df.to_csv(file_path, index = False, mode='w')
read_df = pd.read_csv(file_path)
print(f"Verifying Data Frame # Rows: {read_df.shape[0]}")
# Out:
# 1/1000 Processing
# 	- Lat: -33.818056
# 	- Lon: 19.694722
# 	- Sample Date: 29-07-2013
#
# 	Skipping... 1 <= 918
# 2/1000 Processing
# 	- Lat: -28.7115
# 	- Lon: 24.07288889
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 2 <= 918
# 3/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 3 <= 918
# 4/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 4 <= 918
# 5/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 5 <= 918
# 6/1000 Processing
# 	- Lat: -25.681111
# 	- Lon: 31.783333
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 6 <= 918
# 7/1000 Processing
# 	- Lat: -25.67386
# 	- Lon: 31.57527
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 7 <= 918
# 8/1000 Processing
# 	- Lat: -25.513889
# 	- Lon: 31.224444
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 8 <= 918
# 9/1000 Processing
# 	- Lat: -24.768889
# 	- Lon: 31.39
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 9 <= 918
# 10/1000 Processing
# 	- Lat: -24.9675
# 	- Lon: 31.516667
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 10 <= 918
# 11/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 11 <= 918
# 12/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 12 <= 918
# 13/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 13 <= 918
# 14/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 14 <= 918
# 15/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 15 <= 918
# 16/1000 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 16 <= 918
# 17/1000 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 17 <= 918
# 18/1000 Processing
# 	- Lat: -29.1825
# 	- Lon: 23.575556
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 18 <= 918
# 19/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 19 <= 918
# 20/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 20 <= 918
# 21/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 21 <= 918
# 22/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 22 <= 918
# 23/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 26-01-2011
#
# 	Skipping... 23 <= 918
# 24/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 23-02-2011
#
# 	Skipping... 24 <= 918
# 25/1000 Processing
# 	- Lat: -25.436111
# 	- Lon: 31.982222
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 25 <= 918
# 26/1000 Processing
# 	- Lat: -25.362222
# 	- Lon: 31.956667
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 26 <= 918
# 27/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 28-06-2011
#
# 	Skipping... 27 <= 918
# 28/1000 Processing
# 	- Lat: -25.398889
# 	- Lon: 31.610556
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 28 <= 918
# 29/1000 Processing
# 	- Lat: -25.14944444
# 	- Lon: 31.94055556
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 29 <= 918
# 30/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 30 <= 918
# 31/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 31 <= 918
# 32/1000 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 32 <= 918
# 33/1000 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 33 <= 918
# 34/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 34 <= 918
# 35/1000 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 35 <= 918
# 36/1000 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 36 <= 918
# 37/1000 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 37 <= 918
# 38/1000 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 38 <= 918
# 39/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 39 <= 918
# 40/1000 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 40 <= 918
# 41/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 41 <= 918
# 42/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 13-05-2015
#
# 	Skipping... 42 <= 918
# 43/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 43 <= 918
# 44/1000 Processing
# 	- Lat: -30.830556
# 	- Lon: 26.921389
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 44 <= 918
# 45/1000 Processing
# 	- Lat: -24.282222
# 	- Lon: 28.090278
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 45 <= 918
# 46/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 46 <= 918
# 47/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 47 <= 918
# 48/1000 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 48 <= 918
# 49/1000 Processing
# 	- Lat: -30.534167
# 	- Lon: 24.961944
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 49 <= 918
# 50/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 14-05-2015
#
# 	Skipping... 50 <= 918
# 51/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 15-05-2015
#
# 	Skipping... 51 <= 918
# 52/1000 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 18-05-2015
#
# 	Skipping... 52 <= 918
# 53/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 18-05-2015
#
# 	Skipping... 53 <= 918
# 54/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 54 <= 918
# 55/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 23-09-2013
#
# 	Skipping... 55 <= 918
# 56/1000 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 56 <= 918
# 57/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 57 <= 918
# 58/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 58 <= 918
# 59/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 59 <= 918
# 60/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 60 <= 918
# 61/1000 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 61 <= 918
# 62/1000 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 62 <= 918
# 63/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 63 <= 918
# 64/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 64 <= 918
# 65/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 65 <= 918
# 66/1000 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 66 <= 918
# 67/1000 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 19-05-2015
#
# 	Skipping... 67 <= 918
# 68/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 68 <= 918
# 69/1000 Processing
# 	- Lat: -22.225556
# 	- Lon: 29.990556
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 69 <= 918
# 70/1000 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 70 <= 918
# 71/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 71 <= 918
# 72/1000 Processing
# 	- Lat: -26.03611
# 	- Lon: 30.99778
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 72 <= 918
# 73/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 73 <= 918
# 74/1000 Processing
# 	- Lat: -27.937778
# 	- Lon: 31.209444
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 74 <= 918
# 75/1000 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 75 <= 918
# 76/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 17-03-2011
#
# 	Skipping... 76 <= 918
# 77/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 13-04-2011
#
# 	Skipping... 77 <= 918
# 78/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 78 <= 918
# 79/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 14-06-2011
#
# 	Skipping... 79 <= 918
# 80/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 15-07-2011
#
# 	Skipping... 80 <= 918
# 81/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 11-08-2011
#
# 	Skipping... 81 <= 918
# 82/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 05-10-2011
#
# 	Skipping... 82 <= 918
# 83/1000 Processing
# 	- Lat: -28.96362
# 	- Lon: 19.15486
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 83 <= 918
# 84/1000 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 84 <= 918
# 85/1000 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 20-05-2015
#
# 	Skipping... 85 <= 918
# 86/1000 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 86 <= 918
# 87/1000 Processing
# 	- Lat: -30.13573889
# 	- Lon: 30.67422222
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 87 <= 918
# 88/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 10-04-2012
#
# 	Skipping... 88 <= 918
# 89/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 08-05-2012
#
# 	Skipping... 89 <= 918
# 90/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 90 <= 918
# 91/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 24-07-2012
#
# 	Skipping... 91 <= 918
# 92/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 22-08-2012
#
# 	Skipping... 92 <= 918
# 93/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 93 <= 918
# 94/1000 Processing
# 	- Lat: -28.376944
# 	- Lon: 24.303056
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 94 <= 918
# 95/1000 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 95 <= 918
# 96/1000 Processing
# 	- Lat: -34.329722
# 	- Lon: 18.990278
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 96 <= 918
# 97/1000 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 97 <= 918
# 98/1000 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 98 <= 918
# 99/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 22-05-2015
#
# 	Skipping... 99 <= 918
# 100/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 22-05-2015
#
# 	Skipping... 100 <= 918
# 101/1000 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 23-05-2015
#
# 	Skipping... 101 <= 918
# 102/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 25-05-2015
#
# 	Skipping... 102 <= 918
# 103/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 25-05-2015
#
# 	Skipping... 103 <= 918
# 104/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 20-08-2013
#
# 	Skipping... 104 <= 918
# 105/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 25-05-2015
#
# 	Skipping... 105 <= 918
# 106/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 08-10-2013
#
# 	Skipping... 106 <= 918
# 107/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 25-05-2015
#
# 	Skipping... 107 <= 918
# 108/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 25-05-2015
#
# 	Skipping... 108 <= 918
# 109/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 26-05-2015
#
# 	Skipping... 109 <= 918
# 110/1000 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 26-05-2015
#
# 	Skipping... 110 <= 918
# 111/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 26-05-2015
#
# 	Skipping... 111 <= 918
# 112/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 26-05-2015
#
# 	Skipping... 112 <= 918
# 113/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 24-06-2014
#
# 	Skipping... 113 <= 918
# 114/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 23-09-2014
#
# 	Skipping... 114 <= 918
# 115/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 26-05-2015
#
# 	Skipping... 115 <= 918
# 116/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 26-05-2015
#
# 	Skipping... 116 <= 918
# 117/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 26-05-2015
#
# 	Skipping... 117 <= 918
# 118/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 27-05-2015
#
# 	Skipping... 118 <= 918
# 119/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 119 <= 918
# 120/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 21-07-2015
#
# 	Skipping... 120 <= 918
# 121/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 18-08-2015
#
# 	Skipping... 121 <= 918
# 122/1000 Processing
# 	- Lat: -22.225556
# 	- Lon: 29.990556
# 	- Sample Date: 27-05-2015
#
# 	Skipping... 122 <= 918
# 123/1000 Processing
# 	- Lat: -24.282222
# 	- Lon: 28.090278
# 	- Sample Date: 27-05-2015
#
# 	Skipping... 123 <= 918
# 124/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 27-05-2015
#
# 	Skipping... 124 <= 918
# 125/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 27-05-2015
#
# 	Skipping... 125 <= 918
# 126/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 27-05-2015
#
# 	Skipping... 126 <= 918
# 127/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 27-05-2015
#
# 	Skipping... 127 <= 918
# 128/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 15-10-2013
#
# 	Skipping... 128 <= 918
# 129/1000 Processing
# 	- Lat: -25.57877778
# 	- Lon: 29.12747222
# 	- Sample Date: 28-05-2015
#
# 	Skipping... 129 <= 918
# 130/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 29-05-2015
#
# 	Skipping... 130 <= 918
# 131/1000 Processing
# 	- Lat: -28.768056
# 	- Lon: 20.720556
# 	- Sample Date: 29-05-2015
#
# 	Skipping... 131 <= 918
# 132/1000 Processing
# 	- Lat: -22.225556
# 	- Lon: 29.990556
# 	- Sample Date: 01-06-2015
#
# 	Skipping... 132 <= 918
# 133/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 23-06-2014
#
# 	Skipping... 133 <= 918
# 134/1000 Processing
# 	- Lat: -26.510278
# 	- Lon: 28.351389
# 	- Sample Date: 01-06-2015
#
# 	Skipping... 134 <= 918
# 135/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 12-08-2014
#
# 	Skipping... 135 <= 918
# 136/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 10-09-2014
#
# 	Skipping... 136 <= 918
# 137/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 22-10-2014
#
# 	Skipping... 137 <= 918
# 138/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 20-11-2014
#
# 	Skipping... 138 <= 918
# 139/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 14-01-2015
#
# 	Skipping... 139 <= 918
# 140/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 18-02-2015
#
# 	Skipping... 140 <= 918
# 141/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 19-03-2015
#
# 	Skipping... 141 <= 918
# 142/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 15-04-2015
#
# 	Skipping... 142 <= 918
# 143/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 01-06-2015
#
# 	Skipping... 143 <= 918
# 144/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 19-08-2015
#
# 	Skipping... 144 <= 918
# 145/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 145 <= 918
# 146/1000 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 01-06-2015
#
# 	Skipping... 146 <= 918
# 147/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 147 <= 918
# 148/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 01-06-2015
#
# 	Skipping... 148 <= 918
# 149/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 149 <= 918
# 150/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 150 <= 918
# 151/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 13-06-2011
#
# 	Skipping... 151 <= 918
# 152/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 152 <= 918
# 153/1000 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 153 <= 918
# 154/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 154 <= 918
# 155/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 155 <= 918
# 156/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 156 <= 918
# 157/1000 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 157 <= 918
# 158/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 158 <= 918
# 159/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 27-07-2012
#
# 	Skipping... 159 <= 918
# 160/1000 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 160 <= 918
# 161/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 161 <= 918
# 162/1000 Processing
# 	- Lat: -34.02861
# 	- Lon: 22.22222
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 162 <= 918
# 163/1000 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 163 <= 918
# 164/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 164 <= 918
# 165/1000 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 02-06-2015
#
# 	Skipping... 165 <= 918
# 166/1000 Processing
# 	- Lat: -30.830556
# 	- Lon: 26.921389
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 166 <= 918
# 167/1000 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 167 <= 918
# 168/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 168 <= 918
# 169/1000 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 169 <= 918
# 170/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 170 <= 918
# 171/1000 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 171 <= 918
# 172/1000 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 172 <= 918
# 173/1000 Processing
# 	- Lat: -30.679722
# 	- Lon: 26.7125
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 173 <= 918
# 174/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 174 <= 918
# 175/1000 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 03-06-2015
#
# 	Skipping... 175 <= 918
# 176/1000 Processing
# 	- Lat: -28.760833
# 	- Lon: 17.730278
# 	- Sample Date: 04-06-2015
#
# 	Skipping... 176 <= 918
# 177/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 09-06-2014
#
# 	Skipping... 177 <= 918
# 178/1000 Processing
# 	- Lat: -28.44555556
# 	- Lon: 32.325
# 	- Sample Date: 28-07-2015
#
# 	Skipping... 178 <= 918
# 179/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 04-06-2015
#
# 	Skipping... 179 <= 918
# 180/1000 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 04-06-2015
#
# 	Skipping... 180 <= 918
# 181/1000 Processing
# 	- Lat: -28.376944
# 	- Lon: 24.303056
# 	- Sample Date: 04-06-2015
#
# 	Skipping... 181 <= 918
# 182/1000 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 04-06-2015
#
# 	Skipping... 182 <= 918
# 183/1000 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 04-06-2015
#
# 	Skipping... 183 <= 918
# 184/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 13-04-2015
#
# 	Skipping... 184 <= 918
# 185/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 04-06-2015
#
# 	Skipping... 185 <= 918
# 186/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 08-06-2015
#
# 	Skipping... 186 <= 918
# 187/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 05-06-2015
#
# 	Skipping... 187 <= 918
# 188/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 17-08-2015
#
# 	Skipping... 188 <= 918
# 189/1000 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 05-06-2015
#
# 	Skipping... 189 <= 918
# 190/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 19-10-2015
#
# 	Skipping... 190 <= 918
# 191/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 08-06-2015
#
# 	Skipping... 191 <= 918
# 192/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 05-01-2011
#
# 	Skipping... 192 <= 918
# 193/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 09-02-2011
#
# 	Skipping... 193 <= 918
# 194/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 16-03-2011
#
# 	Skipping... 194 <= 918
# 195/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 12-04-2011
#
# 	Skipping... 195 <= 918
# 196/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 08-06-2015
#
# 	Skipping... 196 <= 918
# 197/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 08-06-2015
#
# 	Skipping... 197 <= 918
# 198/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 08-06-2015
#
# 	Skipping... 198 <= 918
# 199/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 08-06-2015
#
# 	Skipping... 199 <= 918
# 200/1000 Processing
# 	- Lat: -33.818056
# 	- Lon: 19.694722
# 	- Sample Date: 08-06-2015
#
# 	Skipping... 200 <= 918
# 201/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 09-11-2011
#
# 	Skipping... 201 <= 918
# 202/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 21-12-2011
#
# 	Skipping... 202 <= 918
# 203/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 17-01-2012
#
# 	Skipping... 203 <= 918
# 204/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 15-02-2012
#
# 	Skipping... 204 <= 918
# 205/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 13-03-2012
#
# 	Skipping... 205 <= 918
# 206/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 17-04-2012
#
# 	Skipping... 206 <= 918
# 207/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 17-05-2012
#
# 	Skipping... 207 <= 918
# 208/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 29-05-2012
#
# 	Skipping... 208 <= 918
# 209/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 209 <= 918
# 210/1000 Processing
# 	- Lat: -25.73411
# 	- Lon: 27.21422
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 210 <= 918
# 211/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 211 <= 918
# 212/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 212 <= 918
# 213/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 23-10-2012
#
# 	Skipping... 213 <= 918
# 214/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 13-11-2012
#
# 	Skipping... 214 <= 918
# 215/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 04-12-2012
#
# 	Skipping... 215 <= 918
# 216/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 26-03-2013
#
# 	Skipping... 216 <= 918
# 217/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 23-04-2013
#
# 	Skipping... 217 <= 918
# 218/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 21-05-2013
#
# 	Skipping... 218 <= 918
# 219/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 219 <= 918
# 220/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 220 <= 918
# 221/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 28-01-2014
#
# 	Skipping... 221 <= 918
# 222/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 12-02-2014
#
# 	Skipping... 222 <= 918
# 223/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 04-03-2014
#
# 	Skipping... 223 <= 918
# 224/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 01-04-2014
#
# 	Skipping... 224 <= 918
# 225/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 13-05-2014
#
# 	Skipping... 225 <= 918
# 226/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 226 <= 918
# 227/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 227 <= 918
# 228/1000 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 228 <= 918
# 229/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 229 <= 918
# 230/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 21-10-2014
#
# 	Skipping... 230 <= 918
# 231/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 25-11-2014
#
# 	Skipping... 231 <= 918
# 232/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 27-01-2015
#
# 	Skipping... 232 <= 918
# 233/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 17-02-2015
#
# 	Skipping... 233 <= 918
# 234/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 17-03-2015
#
# 	Skipping... 234 <= 918
# 235/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 14-04-2015
#
# 	Skipping... 235 <= 918
# 236/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 12-05-2015
#
# 	Skipping... 236 <= 918
# 237/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 237 <= 918
# 238/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 238 <= 918
# 239/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 239 <= 918
# 240/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 240 <= 918
# 241/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 241 <= 918
# 242/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 242 <= 918
# 243/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 10-05-2011
#
# 	Skipping... 243 <= 918
# 244/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 13-06-2011
#
# 	Skipping... 244 <= 918
# 245/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 12-07-2011
#
# 	Skipping... 245 <= 918
# 246/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 10-08-2011
#
# 	Skipping... 246 <= 918
# 247/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 06-09-2011
#
# 	Skipping... 247 <= 918
# 248/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 03-11-2011
#
# 	Skipping... 248 <= 918
# 249/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 29-05-2012
#
# 	Skipping... 249 <= 918
# 250/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 03-07-2012
#
# 	Skipping... 250 <= 918
# 251/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 31-07-2012
#
# 	Skipping... 251 <= 918
# 252/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 28-08-2012
#
# 	Skipping... 252 <= 918
# 253/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 26-09-2012
#
# 	Skipping... 253 <= 918
# 254/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 23-10-2012
#
# 	Skipping... 254 <= 918
# 255/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 255 <= 918
# 256/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 256 <= 918
# 257/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 257 <= 918
# 258/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 10-09-2013
#
# 	Skipping... 258 <= 918
# 259/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 09-10-2013
#
# 	Skipping... 259 <= 918
# 260/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 05-11-2013
#
# 	Skipping... 260 <= 918
# 261/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 26-11-2013
#
# 	Skipping... 261 <= 918
# 262/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 12-06-2014
#
# 	Skipping... 262 <= 918
# 263/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 17-07-2014
#
# 	Skipping... 263 <= 918
# 264/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 28-08-2014
#
# 	Skipping... 264 <= 918
# 265/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 25-09-2014
#
# 	Skipping... 265 <= 918
# 266/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 23-10-2014
#
# 	Skipping... 266 <= 918
# 267/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 27-11-2014
#
# 	Skipping... 267 <= 918
# 268/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 25-02-2015
#
# 	Skipping... 268 <= 918
# 269/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 269 <= 918
# 270/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 26-06-2015
#
# 	Skipping... 270 <= 918
# 271/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 30-07-2015
#
# 	Skipping... 271 <= 918
# 272/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 27-08-2015
#
# 	Skipping... 272 <= 918
# 273/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 29-10-2015
#
# 	Skipping... 273 <= 918
# 274/1000 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 274 <= 918
# 275/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 09-06-2015
#
# 	Skipping... 275 <= 918
# 276/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 276 <= 918
# 277/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 277 <= 918
# 278/1000 Processing
# 	- Lat: -24.282222
# 	- Lon: 28.090278
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 278 <= 918
# 279/1000 Processing
# 	- Lat: -23.763056
# 	- Lon: 27.908611
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 279 <= 918
# 280/1000 Processing
# 	- Lat: -23.23572222
# 	- Lon: 27.717
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 280 <= 918
# 281/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 281 <= 918
# 282/1000 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 282 <= 918
# 283/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 283 <= 918
# 284/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 284 <= 918
# 285/1000 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 285 <= 918
# 286/1000 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 286 <= 918
# 287/1000 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 287 <= 918
# 288/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 288 <= 918
# 289/1000 Processing
# 	- Lat: -25.57877778
# 	- Lon: 29.12747222
# 	- Sample Date: 10-06-2015
#
# 	Skipping... 289 <= 918
# 290/1000 Processing
# 	- Lat: -22.225556
# 	- Lon: 29.990556
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 290 <= 918
# 291/1000 Processing
# 	- Lat: -30.830556
# 	- Lon: 26.921389
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 291 <= 918
# 292/1000 Processing
# 	- Lat: -24.95861111
# 	- Lon: 29.39527778
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 292 <= 918
# 293/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 293 <= 918
# 294/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 294 <= 918
# 295/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 295 <= 918
# 296/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 296 <= 918
# 297/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 297 <= 918
# 298/1000 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 298 <= 918
# 299/1000 Processing
# 	- Lat: -30.679722
# 	- Lon: 26.7125
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 299 <= 918
# 300/1000 Processing
# 	- Lat: -30.534167
# 	- Lon: 24.961944
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 300 <= 918
# 301/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 301 <= 918
# 302/1000 Processing
# 	- Lat: -33.72266667
# 	- Lon: 18.61691667
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 302 <= 918
# 303/1000 Processing
# 	- Lat: -27.356667
# 	- Lon: 27.286389
# 	- Sample Date: 11-06-2015
#
# 	Skipping... 303 <= 918
# 304/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 12-06-2015
#
# 	Skipping... 304 <= 918
# 305/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 12-06-2015
#
# 	Skipping... 305 <= 918
# 306/1000 Processing
# 	- Lat: -26.619444
# 	- Lon: 27.980833
# 	- Sample Date: 12-06-2015
#
# 	Skipping... 306 <= 918
# 307/1000 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 12-06-2015
#
# 	Skipping... 307 <= 918
# 308/1000 Processing
# 	- Lat: -29.658056
# 	- Lon: 25.973333
# 	- Sample Date: 12-06-2015
#
# 	Skipping... 308 <= 918
# 309/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 15-06-2015
#
# 	Skipping... 309 <= 918
# 310/1000 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 15-06-2015
#
# 	Skipping... 310 <= 918
# 311/1000 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 15-06-2015
#
# 	Skipping... 311 <= 918
# 312/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 15-06-2015
#
# 	Skipping... 312 <= 918
# 313/1000 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 16-06-2015
#
# 	Skipping... 313 <= 918
# 314/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 16-06-2015
#
# 	Skipping... 314 <= 918
# 315/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 16-06-2015
#
# 	Skipping... 315 <= 918
# 316/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 16-06-2015
#
# 	Skipping... 316 <= 918
# 317/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 16-06-2015
#
# 	Skipping... 317 <= 918
# 318/1000 Processing
# 	- Lat: -22.769722
# 	- Lon: 30.886944
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 318 <= 918
# 319/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 319 <= 918
# 320/1000 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 320 <= 918
# 321/1000 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 321 <= 918
# 322/1000 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 322 <= 918
# 323/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 323 <= 918
# 324/1000 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 324 <= 918
# 325/1000 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 17-06-2015
#
# 	Skipping... 325 <= 918
# 326/1000 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 326 <= 918
# 327/1000 Processing
# 	- Lat: -30.13573889
# 	- Lon: 30.67422222
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 327 <= 918
# 328/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 328 <= 918
# 329/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 329 <= 918
# 330/1000 Processing
# 	- Lat: -28.376944
# 	- Lon: 24.303056
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 330 <= 918
# 331/1000 Processing
# 	- Lat: -31.394444
# 	- Lon: 20.947222
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 331 <= 918
# 332/1000 Processing
# 	- Lat: -29.651389
# 	- Lon: 22.746389
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 332 <= 918
# 333/1000 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 18-06-2015
#
# 	Skipping... 333 <= 918
# 334/1000 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 04-07-2012
#
# 	Skipping... 334 <= 918
# 335/1000 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 19-06-2015
#
# 	Skipping... 335 <= 918
# 336/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 19-06-2015
#
# 	Skipping... 336 <= 918
# 337/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 19-06-2015
#
# 	Skipping... 337 <= 918
# 338/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 338 <= 918
# 339/1000 Processing
# 	- Lat: -25.49037
# 	- Lon: 30.6986
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 339 <= 918
# 340/1000 Processing
# 	- Lat: -24.99328
# 	- Lon: 30.81444
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 340 <= 918
# 341/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 341 <= 918
# 342/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 342 <= 918
# 343/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 343 <= 918
# 344/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 344 <= 918
# 345/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 22-06-2015
#
# 	Skipping... 345 <= 918
# 346/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 346 <= 918
# 347/1000 Processing
# 	- Lat: -25.436111
# 	- Lon: 31.982222
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 347 <= 918
# 348/1000 Processing
# 	- Lat: -29.140556
# 	- Lon: 31.391944
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 348 <= 918
# 349/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 349 <= 918
# 350/1000 Processing
# 	- Lat: -22.43772222
# 	- Lon: 31.07805556
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 350 <= 918
# 351/1000 Processing
# 	- Lat: -25.681111
# 	- Lon: 31.783333
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 351 <= 918
# 352/1000 Processing
# 	- Lat: -25.67386
# 	- Lon: 31.57527
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 352 <= 918
# 353/1000 Processing
# 	- Lat: -25.398889
# 	- Lon: 31.610556
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 353 <= 918
# 354/1000 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 354 <= 918
# 355/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 355 <= 918
# 356/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 356 <= 918
# 357/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 357 <= 918
# 358/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 23-06-2015
#
# 	Skipping... 358 <= 918
# 359/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 359 <= 918
# 360/1000 Processing
# 	- Lat: -31.860278
# 	- Lon: 18.6875
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 360 <= 918
# 361/1000 Processing
# 	- Lat: -25.362222
# 	- Lon: 31.956667
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 361 <= 918
# 362/1000 Processing
# 	- Lat: -24.768889
# 	- Lon: 31.39
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 362 <= 918
# 363/1000 Processing
# 	- Lat: -24.9675
# 	- Lon: 31.516667
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 363 <= 918
# 364/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 364 <= 918
# 365/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 365 <= 918
# 366/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 24-06-2015
#
# 	Skipping... 366 <= 918
# 367/1000 Processing
# 	- Lat: -26.03611
# 	- Lon: 30.99778
# 	- Sample Date: 25-06-2015
#
# 	Skipping... 367 <= 918
# 368/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 17-02-2011
#
# 	Skipping... 368 <= 918
# 369/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 25-06-2015
#
# 	Skipping... 369 <= 918
# 370/1000 Processing
# 	- Lat: -28.460833
# 	- Lon: 21.248889
# 	- Sample Date: 25-06-2015
#
# 	Skipping... 370 <= 918
# 371/1000 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 25-06-2015
#
# 	Skipping... 371 <= 918
# 372/1000 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 25-06-2015
#
# 	Skipping... 372 <= 918
# 373/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 25-01-2012
#
# 	Skipping... 373 <= 918
# 374/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 22-02-2012
#
# 	Skipping... 374 <= 918
# 375/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 21-03-2012
#
# 	Skipping... 375 <= 918
# 376/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 26-06-2015
#
# 	Skipping... 376 <= 918
# 377/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 29-06-2015
#
# 	Skipping... 377 <= 918
# 378/1000 Processing
# 	- Lat: -26.510278
# 	- Lon: 28.351389
# 	- Sample Date: 29-06-2015
#
# 	Skipping... 378 <= 918
# 379/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 29-06-2015
#
# 	Skipping... 379 <= 918
# 380/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 29-06-2015
#
# 	Skipping... 380 <= 918
# 381/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 381 <= 918
# 382/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 382 <= 918
# 383/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 383 <= 918
# 384/1000 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 384 <= 918
# 385/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 385 <= 918
# 386/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 386 <= 918
# 387/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 387 <= 918
# 388/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 388 <= 918
# 389/1000 Processing
# 	- Lat: -31.436944
# 	- Lon: 20.474722
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 389 <= 918
# 390/1000 Processing
# 	- Lat: -29.651389
# 	- Lon: 22.746389
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 390 <= 918
# 391/1000 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 391 <= 918
# 392/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 392 <= 918
# 393/1000 Processing
# 	- Lat: -28.308889
# 	- Lon: 31.9025
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 393 <= 918
# 394/1000 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 30-06-2015
#
# 	Skipping... 394 <= 918
# 395/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 395 <= 918
# 396/1000 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 396 <= 918
# 397/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 397 <= 918
# 398/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 398 <= 918
# 399/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 399 <= 918
# 400/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 400 <= 918
# 401/1000 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 401 <= 918
# 402/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 28-01-2015
#
# 	Skipping... 402 <= 918
# 403/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 19-02-2015
#
# 	Skipping... 403 <= 918
# 404/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 25-03-2015
#
# 	Skipping... 404 <= 918
# 405/1000 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 405 <= 918
# 406/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 406 <= 918
# 407/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 01-07-2015
#
# 	Skipping... 407 <= 918
# 408/1000 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 02-07-2015
#
# 	Skipping... 408 <= 918
# 409/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 02-07-2015
#
# 	Skipping... 409 <= 918
# 410/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 02-07-2015
#
# 	Skipping... 410 <= 918
# 411/1000 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 02-07-2015
#
# 	Skipping... 411 <= 918
# 412/1000 Processing
# 	- Lat: -28.376944
# 	- Lon: 24.303056
# 	- Sample Date: 02-07-2015
#
# 	Skipping... 412 <= 918
# 413/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 03-07-2015
#
# 	Skipping... 413 <= 918
# 414/1000 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 03-07-2015
#
# 	Skipping... 414 <= 918
# 415/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 03-07-2015
#
# 	Skipping... 415 <= 918
# 416/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 06-07-2015
#
# 	Skipping... 416 <= 918
# 417/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 06-07-2015
#
# 	Skipping... 417 <= 918
# 418/1000 Processing
# 	- Lat: -22.225556
# 	- Lon: 29.990556
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 418 <= 918
# 419/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 419 <= 918
# 420/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 420 <= 918
# 421/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 421 <= 918
# 422/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 422 <= 918
# 423/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 423 <= 918
# 424/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 424 <= 918
# 425/1000 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 425 <= 918
# 426/1000 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 426 <= 918
# 427/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 07-07-2015
#
# 	Skipping... 427 <= 918
# 428/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 428 <= 918
# 429/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 429 <= 918
# 430/1000 Processing
# 	- Lat: -23.23572222
# 	- Lon: 27.717
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 430 <= 918
# 431/1000 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 431 <= 918
# 432/1000 Processing
# 	- Lat: -22.91028
# 	- Lon: 29.61111
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 432 <= 918
# 433/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 433 <= 918
# 434/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 434 <= 918
# 435/1000 Processing
# 	- Lat: -30.534167
# 	- Lon: 24.961944
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 435 <= 918
# 436/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 436 <= 918
# 437/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 437 <= 918
# 438/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 438 <= 918
# 439/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 439 <= 918
# 440/1000 Processing
# 	- Lat: -34.02861
# 	- Lon: 22.22222
# 	- Sample Date: 08-07-2015
#
# 	Skipping... 440 <= 918
# 441/1000 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 03-12-2015
#
# 	Skipping... 441 <= 918
# 442/1000 Processing
# 	- Lat: -33.464444
# 	- Lon: 18.740556
# 	- Sample Date: 20-07-2011
#
# 	Skipping... 442 <= 918
# 443/1000 Processing
# 	- Lat: -33.464444
# 	- Lon: 18.740556
# 	- Sample Date: 17-08-2011
#
# 	Skipping... 443 <= 918
# 444/1000 Processing
# 	- Lat: -33.464444
# 	- Lon: 18.740556
# 	- Sample Date: 14-09-2011
#
# 	Skipping... 444 <= 918
# 445/1000 Processing
# 	- Lat: -33.464444
# 	- Lon: 18.740556
# ...
#
# 	Skipping... 857 <= 918
# 858/1000 Processing
# 	- Lat: -24.95861111
# 	- Lon: 29.39527778
# 	- Sample Date: 11-09-2015
#
# 	Skipping... 858 <= 918
# 859/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 11-09-2015
#
# 	Skipping... 859 <= 918
# 860/1000 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 11-09-2015
#
# 	Skipping... 860 <= 918
# 861/1000 Processing
# 	- Lat: -29.651389
# 	- Lon: 22.746389
# 	- Sample Date: 11-09-2015
#
# 	Skipping... 861 <= 918
# 862/1000 Processing
# 	- Lat: -29.1825
# 	- Lon: 23.575556
# 	- Sample Date: 11-09-2015
#
# 	Skipping... 862 <= 918
# 863/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 11-09-2015
#
# 	Skipping... 863 <= 918
# 864/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 14-09-2015
#
# 	Skipping... 864 <= 918
# 865/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 14-09-2015
#
# 	Skipping... 865 <= 918
# 866/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 14-09-2015
#
# 	Skipping... 866 <= 918
# 867/1000 Processing
# 	- Lat: -29.140556
# 	- Lon: 31.391944
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 867 <= 918
# 868/1000 Processing
# 	- Lat: -31.860278
# 	- Lon: 18.6875
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 868 <= 918
# 869/1000 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 869 <= 918
# 870/1000 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 870 <= 918
# 871/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 871 <= 918
# 872/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 872 <= 918
# 873/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 873 <= 918
# 874/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 874 <= 918
# 875/1000 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 875 <= 918
# 876/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 876 <= 918
# 877/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 877 <= 918
# 878/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 15-09-2015
#
# 	Skipping... 878 <= 918
# 879/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 879 <= 918
# 880/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 880 <= 918
# 881/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 881 <= 918
# 882/1000 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 882 <= 918
# 883/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 883 <= 918
# 884/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 884 <= 918
# 885/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 885 <= 918
# 886/1000 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 886 <= 918
# 887/1000 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 16-09-2015
#
# 	Skipping... 887 <= 918
# 888/1000 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 17-09-2015
#
# 	Skipping... 888 <= 918
# 889/1000 Processing
# 	- Lat: -26.03611
# 	- Lon: 30.99778
# 	- Sample Date: 17-09-2015
#
# 	Skipping... 889 <= 918
# 890/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 17-09-2015
#
# 	Skipping... 890 <= 918
# 891/1000 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 17-09-2015
#
# 	Skipping... 891 <= 918
# 892/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 17-09-2015
#
# 	Skipping... 892 <= 918
# 893/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 17-09-2015
#
# 	Skipping... 893 <= 918
# 894/1000 Processing
# 	- Lat: -28.44555556
# 	- Lon: 32.325
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 894 <= 918
# 895/1000 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 895 <= 918
# 896/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 896 <= 918
# 897/1000 Processing
# 	- Lat: -26.619444
# 	- Lon: 27.980833
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 897 <= 918
# 898/1000 Processing
# 	- Lat: -26.510278
# 	- Lon: 28.351389
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 898 <= 918
# 899/1000 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 899 <= 918
# 900/1000 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 900 <= 918
# 901/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 901 <= 918
# 902/1000 Processing
# 	- Lat: -28.308889
# 	- Lon: 31.9025
# 	- Sample Date: 21-09-2015
#
# 	Skipping... 902 <= 918
# 903/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 22-09-2015
#
# 	Skipping... 903 <= 918
# 904/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 22-09-2015
#
# 	Skipping... 904 <= 918
# 905/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 22-09-2015
#
# 	Skipping... 905 <= 918
# 906/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 22-09-2015
#
# 	Skipping... 906 <= 918
# 907/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 23-09-2015
#
# 	Skipping... 907 <= 918
# 908/1000 Processing
# 	- Lat: -28.7115
# 	- Lon: 24.07288889
# 	- Sample Date: 23-09-2015
#
# 	Skipping... 908 <= 918
# 909/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 23-09-2015
#
# 	Skipping... 909 <= 918
# 910/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 23-09-2015
#
# 	Skipping... 910 <= 918
# 911/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 23-09-2015
#
# 	Skipping... 911 <= 918
# 912/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 23-09-2015
#
# 	Skipping... 912 <= 918
# 913/1000 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 23-09-2015
#
# 	Skipping... 913 <= 918
# 914/1000 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 24-09-2015
#
# 	Skipping... 914 <= 918
# 915/1000 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 24-09-2015
#
# 	Skipping... 915 <= 918
# 916/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 24-09-2015
#
# 	Skipping... 916 <= 918
# 917/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 25-09-2015
#
# 	Skipping... 917 <= 918
# 918/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 25-09-2015
#
# 	Skipping... 918 <= 918
# 919/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 28-09-2015
#
# len_full_df = 919, count = 0
# 920/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 28-09-2015
#
# len_full_df = 920, count = 0
# 921/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 29-09-2015
#
# len_full_df = 921, count = 0
# 922/1000 Processing
# 	- Lat: -24.99328
# 	- Lon: 30.81444
# 	- Sample Date: 29-09-2015
#
# len_full_df = 922, count = 0
# 923/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 29-09-2015
#
# len_full_df = 923, count = 0
# 924/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 29-09-2015
#
# len_full_df = 924, count = 0
# 925/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 29-09-2015
#
# len_full_df = 925, count = 0
# 926/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 29-09-2015
#
# len_full_df = 926, count = 0
# 927/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 29-09-2015
#
# len_full_df = 927, count = 0
# 928/1000 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 29-09-2015
#
# len_full_df = 928, count = 0
# 929/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 29-09-2015
#
# len_full_df = 929, count = 0
# 930/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 30-09-2015
#
# len_full_df = 930, count = 0
# 931/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 30-09-2015
#
# len_full_df = 931, count = 0
# 932/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 30-09-2015
#
# len_full_df = 932, count = 0
# 933/1000 Processing
# 	- Lat: -24.768889
# 	- Lon: 31.39
# 	- Sample Date: 30-09-2015
#
# len_full_df = 933, count = 0
# 934/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 30-09-2015
#
# len_full_df = 934, count = 0
# 935/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 30-09-2015
#
# len_full_df = 935, count = 0
# 936/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 30-09-2015
#
# len_full_df = 936, count = 0
# 937/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 30-09-2015
#
# len_full_df = 937, count = 0
# 938/1000 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 30-09-2015
#
# len_full_df = 938, count = 0
# 939/1000 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 30-09-2015
#
# len_full_df = 939, count = 0
# 940/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 30-09-2015
#
# len_full_df = 940, count = 0
# 941/1000 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 30-09-2015
#
# len_full_df = 941, count = 0
# 942/1000 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 30-09-2015
#
# len_full_df = 942, count = 0
# 943/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 01-10-2015
#
# len_full_df = 943, count = 0
# 944/1000 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 01-10-2015
#
# len_full_df = 944, count = 0
# 945/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 01-10-2015
#
# len_full_df = 945, count = 0
# 946/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 01-10-2015
#
# len_full_df = 946, count = 0
# 947/1000 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 01-10-2015
#
# len_full_df = 947, count = 0
# 948/1000 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 01-10-2015
#
# len_full_df = 948, count = 0
# 949/1000 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 05-10-2015
#
# len_full_df = 949, count = 0
# 950/1000 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 05-10-2015
#
# len_full_df = 950, count = 0
# 951/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 05-10-2015
#
# len_full_df = 951, count = 0
# 952/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 05-10-2015
#
# len_full_df = 952, count = 0
# 953/1000 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 05-10-2015
#
# len_full_df = 953, count = 0
# 954/1000 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 06-10-2015
#
# len_full_df = 954, count = 0
# 955/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 06-10-2015
#
# len_full_df = 955, count = 0
# 956/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 06-10-2015
#
# len_full_df = 956, count = 0
# 957/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 06-10-2015
#
# len_full_df = 957, count = 0
# 958/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 06-10-2015
#
# len_full_df = 958, count = 0
# 959/1000 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 06-10-2015
#
# len_full_df = 959, count = 0
# 960/1000 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 06-10-2015
#
# len_full_df = 960, count = 0
# 961/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 06-10-2015
#
# len_full_df = 961, count = 0
# 962/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 06-10-2015
#
# len_full_df = 962, count = 0
# 963/1000 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 06-10-2015
#
# len_full_df = 963, count = 0
# 964/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 06-10-2015
#
# len_full_df = 964, count = 0
# 965/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 07-10-2015
#
# len_full_df = 965, count = 0
# 966/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 07-10-2015
#
# len_full_df = 966, count = 0
# 967/1000 Processing
# 	- Lat: -27.937778
# 	- Lon: 31.209444
# 	- Sample Date: 07-10-2015
#
# len_full_df = 967, count = 0
# 968/1000 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 07-10-2015
#
# len_full_df = 968, count = 0
# 969/1000 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 07-10-2015
#
# len_full_df = 969, count = 0
# 970/1000 Processing
# 	- Lat: -34.02861
# 	- Lon: 22.22222
# 	- Sample Date: 07-10-2015
#
# len_full_df = 970, count = 0
# 971/1000 Processing
# 	- Lat: -34.005833
# 	- Lon: 22.351111
# 	- Sample Date: 07-10-2015
#
# len_full_df = 971, count = 0
# 972/1000 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 07-10-2015
#
# len_full_df = 972, count = 0
# 973/1000 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 08-10-2015
#
# len_full_df = 973, count = 0
# 974/1000 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 08-10-2015
#
# len_full_df = 974, count = 0
# 975/1000 Processing
# 	- Lat: -30.13573889
# 	- Lon: 30.67422222
# 	- Sample Date: 08-10-2015
#
# len_full_df = 975, count = 0
# 976/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 08-10-2015
#
# len_full_df = 976, count = 0
# 977/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 08-10-2015
#
# len_full_df = 977, count = 0
# 978/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 08-10-2015
#
# len_full_df = 978, count = 0
# 979/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 09-10-2015
#
# len_full_df = 979, count = 0
# 980/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 09-10-2015
#
# len_full_df = 980, count = 0
# 981/1000 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 09-10-2015
#
# len_full_df = 981, count = 0
# 982/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 09-10-2015
#
# len_full_df = 982, count = 0
# 983/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 09-10-2015
#
# len_full_df = 983, count = 0
# 984/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 12-10-2015
#
# len_full_df = 984, count = 0
# 985/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 12-10-2015
#
# len_full_df = 985, count = 0
# 986/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 12-10-2015
#
# len_full_df = 986, count = 0
# 987/1000 Processing
# 	- Lat: -29.140556
# 	- Lon: 31.391944
# 	- Sample Date: 13-10-2015
#
# len_full_df = 987, count = 0
# 988/1000 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 13-10-2015
#
# len_full_df = 988, count = 0
# 989/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 13-10-2015
#
# len_full_df = 989, count = 0
# 990/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 13-10-2015
#
# len_full_df = 990, count = 0
# 991/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 13-10-2015
#
# len_full_df = 991, count = 0
# 992/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 13-10-2015
#
# len_full_df = 992, count = 0
# 993/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 13-10-2015
#
# len_full_df = 993, count = 0
# 994/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 13-10-2015
#
# len_full_df = 994, count = 0
# 995/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 13-10-2015
#
# len_full_df = 995, count = 0
# 996/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 14-10-2015
#
# len_full_df = 996, count = 0
# 997/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 14-10-2015
#
# len_full_df = 997, count = 0
# 998/1000 Processing
# 	- Lat: -25.73411
# 	- Lon: 27.21422
# 	- Sample Date: 14-10-2015
#
# len_full_df = 998, count = 0
# 999/1000 Processing
# 	- Lat: -22.769722
# 	- Lon: 30.886944
# 	- Sample Date: 14-10-2015
#
# len_full_df = 999, count = 0
# 1000/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 14-10-2015
#
# len_full_df = 1000, count = 0
# Verifying Data Frame # Rows: 1000

# %%
# session.sql(f"""
#     PUT file://{file_path}
#     'snow://workspace/USER$.PUBLIC."EY-AI-and-Data-Challenge-v2"/versions/live/'
#     AUTO_COMPRESS=FALSE
#     OVERWRITE=TRUE
# """).collect()
#
# print("File saved! Refresh the browser to see the files in the sidebar")
