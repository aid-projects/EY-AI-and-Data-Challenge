# %%
# !pip install uv
# !uv pip install  -r requirements.txt

# %%
import time
# import snowflake
# from snowflake.snowpark.context import get_active_session
# session = get_active_session()

import warnings
warnings.filterwarnings("ignore")

# Data manipulation and analysis
import numpy as np
import pandas as pd

# Planetary Computer tools for STAC API access and authentication
import pystac_client
import planetary_computer as pc
from odc.stac import stac_load
from pystac.extensions.eo import EOExtension as eo

from datetime import date
from tqdm import tqdm
import os
import time

# %%
# Setup
tqdm.pandas()

catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=pc.sign_inplace,
    )

bands_of_interest = {'red', 'blue', 'drad', 'emis', 'emsd', 'lwir', 'trad', 'urad', 'atran', 'cdist', 'green', 'nir08', 'swir16', 'swir22', 'atmos_opacity'}

def compute_Landsat_values(row):
    lat = row['Latitude']
    lon = row['Longitude']
    date = pd.to_datetime(row['Sample Date'], dayfirst=True, errors='coerce')


    # Buffer size for ~100m 
    bbox_size = 0.00089831  
    bbox = [
        lon - bbox_size / 2,
        lat - bbox_size / 2,
        lon + bbox_size / 2,
        lat + bbox_size / 2
    ]

    # Wider search range, we'll filter to nearest date later
    search = catalog.search(
        collections=["landsat-c2-l2"],
        bbox=bbox,
        datetime="2011-01-01/2015-12-31",
        query={"eo:cloud_cover": {"lt": 10}},
    )
    
    items = search.item_collection()

    if not items:
        # return pd.Series({
        #     "nir": np.nan
        #     , "green": np.nan
        #     , "swir16": np.nan
        #     , "swir22": np.nan
        #     , "red": np.nan
        #     , "blue": np.nan
        # })
        print("No items found")
        return pd.Series([np.nan] * len(bands_of_interest), index=bands_of_interest)


    # Convert sample date to UTC
    sample_date_utc = date.tz_localize("UTC") if date.tzinfo is None else date.tz_convert("UTC")

    # Pick the item closest to the sample date
    items = sorted(
        items,
        key=lambda x: abs(pd.to_datetime(x.properties["datetime"]).tz_convert("UTC") - sample_date_utc)
    )
    selected_item = pc.sign(items[0])

    # max_key_length = len(max(selected_item.assets, key=len))
    # for key, asset in selected_item.assets.items():
    #     print(f"{key.rjust(max_key_length)}: {asset.title}")

    # Load required bands
    # bands_of_interest = ["green", "nir08", "swir16", "swir22", "red", "blue"]
    bands_to_extract = [band for band in bands_of_interest if band in selected_item.assets.keys()]
    data = stac_load([selected_item], bands=bands_to_extract, bbox=bbox).isel(time=0)


    medians = []
    for band_name in bands_of_interest:
        if band_name in selected_item.assets.keys():
            band = data[band_name].astype("float")
            # Compute medians
            median_band = float(band.median(skipna=True).values)
            # Replace 0 with NaN
            median_band = median_band if median_band != 0 else np.nan
            medians.append(median_band)
        else:
            medians.append(np.nan)
    # print(pd.Series(medians, index=bands_of_interest))
    return pd.Series(medians, index=bands_of_interest)

# %%
Water_Quality_df=pd.read_csv('../water_quality_training_dataset.csv')
display(Water_Quality_df.head())
# Out:
#     Latitude  Longitude Sample Date  Total Alkalinity  Electrical Conductance  \
# 0 -28.760833  17.730278  02-01-2011           128.912                   555.0
# 1 -26.861111  28.884722  03-01-2011            74.720                   162.9
# 2 -26.450000  28.085833  03-01-2011            89.254                   573.0
# 3 -27.671111  27.236944  03-01-2011            82.000                   203.6
# 4 -27.356667  27.286389  03-01-2011            56.100                   145.1
#
#    Dissolved Reactive Phosphorus
# 0                           10.0
# 1                          163.0
# 2                           80.0
# 3                          101.0
# 4                          151.0

# %%
start_index = 9000
end_index = 9319
start_end_index_diff = end_index - start_index
to_process_df = Water_Quality_df[start_index:end_index]
print(to_process_df.shape)
# Out:
# (319, 6)

# %%
len_full_df = 0
count=0
file_path = f"all_bands_extraction/landsat_features_training_all_bands_{start_index}_{end_index}.csv"
full_df = None
while len_full_df < start_end_index_diff and count < 20:

    file_path = f"all_bands_extraction/landsat_features_training_all_bands_{start_index}_{end_index}.csv"
    full_df = None
    if os.path.isfile(file_path):
        full_df = pd.read_csv(file_path)

    len_to_process_df = to_process_df.shape[0]

    for index, row in to_process_df.iterrows():
        try:
            lon = row["Longitude"]
            lat = row["Latitude"]
            sample_date = row["Sample Date"]
            print(f"{index - start_index + 1}/{len_to_process_df} Processing\n\t- Lat: {lat}\n\t- Lon: {lon}\n\t- Sample Date: {sample_date}\n")

            if full_df is not None and index - start_index + 1 <= full_df.shape[0]:
                len_full_df = full_df.shape[0]
                print(f"\tSkipping... {index - start_index + 1} <= {full_df.shape[0]}")
                continue

            new_row = compute_Landsat_values(row)

            row_df = row.to_frame().T
            row_df = row_df[["Latitude", "Longitude", "Sample Date"]]
            new_row_df = new_row.to_frame().T

            row_df = row_df.reset_index(drop=True)
            new_row_df = new_row_df.reset_index(drop=True)
            new_row_df = pd.concat([row_df, new_row_df], axis=1)

            # print(new_row)
            if full_df is None:
                full_df = new_row_df
                print(full_df)
            else:
                full_df = full_df.reset_index(drop=True)
                full_df = pd.concat([full_df, new_row_df], axis=0, ignore_index=True)

            len_full_df = full_df.shape[0]

            print(f"len_full_df = {len_full_df}, count = {count}")
        except Exception as e:
            full_df.to_csv(file_path, index = False, mode='w')
            print(f"Failed !!!\n{e}")
            count+=1
            break

full_df.to_csv(file_path, index = False, mode='w')
read_df = pd.read_csv(file_path)
print(f"Verifying Data Frame # Rows: {read_df.shape[0]}")
# Out:
# 1/319 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 14-10-2015
#
# 	Skipping... 1 <= 312
# 2/319 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 14-10-2015
#
# 	Skipping... 2 <= 312
# 3/319 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 14-10-2015
#
# 	Skipping... 3 <= 312
# 4/319 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 14-10-2015
#
# 	Skipping... 4 <= 312
# 5/319 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 14-10-2015
#
# 	Skipping... 5 <= 312
# 6/319 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 14-10-2015
#
# 	Skipping... 6 <= 312
# 7/319 Processing
# 	- Lat: -26.03611
# 	- Lon: 30.99778
# 	- Sample Date: 15-10-2015
#
# 	Skipping... 7 <= 312
# 8/319 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 15-10-2015
#
# 	Skipping... 8 <= 312
# 9/319 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 16-10-2015
#
# 	Skipping... 9 <= 312
# 10/319 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 19-10-2015
#
# 	Skipping... 10 <= 312
# 11/319 Processing
# 	- Lat: -26.619444
# 	- Lon: 27.980833
# 	- Sample Date: 19-10-2015
#
# 	Skipping... 11 <= 312
# 12/319 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 19-10-2015
#
# 	Skipping... 12 <= 312
# 13/319 Processing
# 	- Lat: -33.818056
# 	- Lon: 19.694722
# 	- Sample Date: 19-10-2015
#
# 	Skipping... 13 <= 312
# 14/319 Processing
# 	- Lat: -25.447222
# 	- Lon: 30.711667
# 	- Sample Date: 19-10-2015
#
# 	Skipping... 14 <= 312
# 15/319 Processing
# 	- Lat: -28.760833
# 	- Lon: 17.730278
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 15 <= 312
# 16/319 Processing
# 	- Lat: -31.860278
# 	- Lon: 18.6875
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 16 <= 312
# 17/319 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 17 <= 312
# 18/319 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 18 <= 312
# 19/319 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 19 <= 312
# 20/319 Processing
# 	- Lat: -25.681111
# 	- Lon: 31.783333
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 20 <= 312
# 21/319 Processing
# 	- Lat: -25.67386
# 	- Lon: 31.57527
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 21 <= 312
# 22/319 Processing
# 	- Lat: -28.44555556
# 	- Lon: 32.325
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 22 <= 312
# 23/319 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 23 <= 312
# 24/319 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 24 <= 312
# 25/319 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 25 <= 312
# 26/319 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 26 <= 312
# 27/319 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 27 <= 312
# 28/319 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 28 <= 312
# 29/319 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 20-10-2015
#
# 	Skipping... 29 <= 312
# 30/319 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 30 <= 312
# 31/319 Processing
# 	- Lat: -30.830556
# 	- Lon: 26.921389
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 31 <= 312
# 32/319 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 32 <= 312
# 33/319 Processing
# 	- Lat: -22.91028
# 	- Lon: 29.61111
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 33 <= 312
# 34/319 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 27-04-2015
#
# 	Skipping... 34 <= 312
# 35/319 Processing
# 	- Lat: -26.006389
# 	- Lon: 29.253889
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 35 <= 312
# 36/319 Processing
# 	- Lat: -25.362222
# 	- Lon: 31.956667
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 36 <= 312
# 37/319 Processing
# 	- Lat: -25.398889
# 	- Lon: 31.610556
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 37 <= 312
# 38/319 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 38 <= 312
# 39/319 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 39 <= 312
# 40/319 Processing
# 	- Lat: -26.510278
# 	- Lon: 28.351389
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 40 <= 312
# 41/319 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 41 <= 312
# 42/319 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 42 <= 312
# 43/319 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 43 <= 312
# 44/319 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 44 <= 312
# 45/319 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 45 <= 312
# 46/319 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 46 <= 312
# 47/319 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 21-10-2015
#
# 	Skipping... 47 <= 312
# 48/319 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 48 <= 312
# 49/319 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 49 <= 312
# 50/319 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 50 <= 312
# 51/319 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 51 <= 312
# 52/319 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 52 <= 312
# 53/319 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 53 <= 312
# 54/319 Processing
# 	- Lat: -30.679722
# 	- Lon: 26.7125
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 54 <= 312
# 55/319 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 22-10-2015
#
# 	Skipping... 55 <= 312
# 56/319 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 23-10-2015
#
# 	Skipping... 56 <= 312
# 57/319 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 23-10-2015
#
# 	Skipping... 57 <= 312
# 58/319 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 23-10-2015
#
# 	Skipping... 58 <= 312
# 59/319 Processing
# 	- Lat: -29.658056
# 	- Lon: 25.973333
# 	- Sample Date: 23-10-2015
#
# 	Skipping... 59 <= 312
# 60/319 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 26-10-2015
#
# 	Skipping... 60 <= 312
# 61/319 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 26-10-2015
#
# 	Skipping... 61 <= 312
# 62/319 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 26-10-2015
#
# 	Skipping... 62 <= 312
# 63/319 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 26-10-2015
#
# 	Skipping... 63 <= 312
# 64/319 Processing
# 	- Lat: -25.73411
# 	- Lon: 27.21422
# 	- Sample Date: 27-10-2015
#
# 	Skipping... 64 <= 312
# 65/319 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 27-10-2015
#
# 	Skipping... 65 <= 312
# 66/319 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 27-10-2015
#
# 	Skipping... 66 <= 312
# 67/319 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 27-10-2015
#
# 	Skipping... 67 <= 312
# 68/319 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 27-10-2015
#
# 	Skipping... 68 <= 312
# 69/319 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 27-10-2015
#
# 	Skipping... 69 <= 312
# 70/319 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 27-10-2015
#
# 	Skipping... 70 <= 312
# 71/319 Processing
# 	- Lat: -28.760833
# 	- Lon: 17.730278
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 71 <= 312
# 72/319 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 72 <= 312
# 73/319 Processing
# 	- Lat: -28.7115
# 	- Lon: 24.07288889
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 73 <= 312
# 74/319 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 74 <= 312
# 75/319 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 75 <= 312
# 76/319 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 76 <= 312
# 77/319 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 77 <= 312
# 78/319 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 78 <= 312
# 79/319 Processing
# 	- Lat: -29.651389
# 	- Lon: 22.746389
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 79 <= 312
# 80/319 Processing
# 	- Lat: -29.1825
# 	- Lon: 23.575556
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 80 <= 312
# 81/319 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 81 <= 312
# 82/319 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 28-10-2015
#
# 	Skipping... 82 <= 312
# 83/319 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 29-10-2015
#
# 	Skipping... 83 <= 312
# 84/319 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 29-10-2015
#
# 	Skipping... 84 <= 312
# 85/319 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 29-10-2015
#
# 	Skipping... 85 <= 312
# 86/319 Processing
# 	- Lat: -34.329722
# 	- Lon: 18.990278
# 	- Sample Date: 29-10-2015
#
# 	Skipping... 86 <= 312
# 87/319 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 29-10-2015
#
# 	Skipping... 87 <= 312
# 88/319 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 30-10-2015
#
# 	Skipping... 88 <= 312
# 89/319 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 30-10-2015
#
# 	Skipping... 89 <= 312
# 90/319 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 30-10-2015
#
# 	Skipping... 90 <= 312
# 91/319 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 01-11-2015
#
# 	Skipping... 91 <= 312
# 92/319 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 02-11-2015
#
# 	Skipping... 92 <= 312
# 93/319 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 02-11-2015
#
# 	Skipping... 93 <= 312
# 94/319 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 03-11-2015
#
# 	Skipping... 94 <= 312
# 95/319 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 03-11-2015
#
# 	Skipping... 95 <= 312
# 96/319 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 03-11-2015
#
# 	Skipping... 96 <= 312
# 97/319 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 03-11-2015
#
# 	Skipping... 97 <= 312
# 98/319 Processing
# 	- Lat: -27.937778
# 	- Lon: 31.209444
# 	- Sample Date: 04-11-2015
#
# 	Skipping... 98 <= 312
# 99/319 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 04-11-2015
#
# 	Skipping... 99 <= 312
# 100/319 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 04-11-2015
#
# 	Skipping... 100 <= 312
# 101/319 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 04-11-2015
#
# 	Skipping... 101 <= 312
# 102/319 Processing
# 	- Lat: -34.005833
# 	- Lon: 22.351111
# 	- Sample Date: 04-11-2015
#
# 	Skipping... 102 <= 312
# 103/319 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 04-11-2015
#
# 	Skipping... 103 <= 312
# 104/319 Processing
# 	- Lat: -22.91028
# 	- Lon: 29.61111
# 	- Sample Date: 05-11-2015
#
# 	Skipping... 104 <= 312
# 105/319 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 05-11-2015
#
# 	Skipping... 105 <= 312
# 106/319 Processing
# 	- Lat: -30.13573889
# 	- Lon: 30.67422222
# 	- Sample Date: 05-11-2015
#
# 	Skipping... 106 <= 312
# 107/319 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 06-11-2015
#
# 	Skipping... 107 <= 312
# 108/319 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 06-11-2015
#
# 	Skipping... 108 <= 312
# 109/319 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 06-11-2015
#
# 	Skipping... 109 <= 312
# 110/319 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 06-11-2015
#
# 	Skipping... 110 <= 312
# 111/319 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 09-11-2015
#
# 	Skipping... 111 <= 312
# 112/319 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 09-11-2015
#
# 	Skipping... 112 <= 312
# 113/319 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 09-11-2015
#
# 	Skipping... 113 <= 312
# 114/319 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 09-11-2015
#
# 	Skipping... 114 <= 312
# 115/319 Processing
# 	- Lat: -29.651389
# 	- Lon: 22.746389
# 	- Sample Date: 09-11-2015
#
# 	Skipping... 115 <= 312
# 116/319 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 116 <= 312
# 117/319 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 117 <= 312
# 118/319 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 118 <= 312
# 119/319 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 119 <= 312
# 120/319 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 120 <= 312
# 121/319 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 121 <= 312
# 122/319 Processing
# 	- Lat: -31.394444
# 	- Lon: 20.947222
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 122 <= 312
# 123/319 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 10-11-2015
#
# 	Skipping... 123 <= 312
# 124/319 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 124 <= 312
# 125/319 Processing
# 	- Lat: -29.140556
# 	- Lon: 31.391944
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 125 <= 312
# 126/319 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 126 <= 312
# 127/319 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 127 <= 312
# 128/319 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 128 <= 312
# 129/319 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 129 <= 312
# 130/319 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 130 <= 312
# 131/319 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 131 <= 312
# 132/319 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 132 <= 312
# 133/319 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 133 <= 312
# 134/319 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 11-11-2015
#
# 	Skipping... 134 <= 312
# 135/319 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 135 <= 312
# 136/319 Processing
# 	- Lat: -30.830556
# 	- Lon: 26.921389
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 136 <= 312
# 137/319 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 137 <= 312
# 138/319 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 138 <= 312
# 139/319 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 139 <= 312
# 140/319 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 140 <= 312
# 141/319 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 141 <= 312
# 142/319 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 142 <= 312
# 143/319 Processing
# 	- Lat: -30.679722
# 	- Lon: 26.7125
# 	- Sample Date: 12-11-2015
#
# 	Skipping... 143 <= 312
# 144/319 Processing
# 	- Lat: -26.619444
# 	- Lon: 27.980833
# 	- Sample Date: 16-11-2015
#
# 	Skipping... 144 <= 312
# 145/319 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 145 <= 312
# 146/319 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 146 <= 312
# 147/319 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 147 <= 312
# 148/319 Processing
# 	- Lat: -24.99328
# 	- Lon: 30.81444
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 148 <= 312
# 149/319 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 149 <= 312
# 150/319 Processing
# 	- Lat: -26.510278
# 	- Lon: 28.351389
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 150 <= 312
# 151/319 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 151 <= 312
# 152/319 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 152 <= 312
# 153/319 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 153 <= 312
# 154/319 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 154 <= 312
# 155/319 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 155 <= 312
# 156/319 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 17-11-2015
#
# 	Skipping... 156 <= 312
# 157/319 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 157 <= 312
# 158/319 Processing
# 	- Lat: -25.73411
# 	- Lon: 27.21422
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 158 <= 312
# 159/319 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 159 <= 312
# 160/319 Processing
# 	- Lat: -24.034167
# 	- Lon: 31.123611
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 160 <= 312
# 161/319 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 161 <= 312
# 162/319 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 162 <= 312
# 163/319 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 163 <= 312
# 164/319 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 164 <= 312
# 165/319 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 165 <= 312
# 166/319 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 166 <= 312
# 167/319 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 18-11-2015
#
# 	Skipping... 167 <= 312
# 168/319 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 19-11-2015
#
# 	Skipping... 168 <= 312
# 169/319 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 19-11-2015
#
# 	Skipping... 169 <= 312
# 170/319 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 19-11-2015
#
# 	Skipping... 170 <= 312
# 171/319 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 19-11-2015
#
# 	Skipping... 171 <= 312
# 172/319 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 20-11-2015
#
# 	Skipping... 172 <= 312
# 173/319 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 20-11-2015
#
# 	Skipping... 173 <= 312
# 174/319 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 20-11-2015
#
# 	Skipping... 174 <= 312
# 175/319 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 23-11-2015
#
# 	Skipping... 175 <= 312
# 176/319 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 23-11-2015
#
# 	Skipping... 176 <= 312
# 177/319 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 23-11-2015
#
# 	Skipping... 177 <= 312
# 178/319 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 23-11-2015
#
# 	Skipping... 178 <= 312
# 179/319 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 23-11-2015
#
# 	Skipping... 179 <= 312
# 180/319 Processing
# 	- Lat: -25.447222
# 	- Lon: 30.711667
# 	- Sample Date: 23-11-2015
#
# 	Skipping... 180 <= 312
# 181/319 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 181 <= 312
# 182/319 Processing
# 	- Lat: -25.681111
# 	- Lon: 31.783333
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 182 <= 312
# 183/319 Processing
# 	- Lat: -25.67386
# 	- Lon: 31.57527
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 183 <= 312
# 184/319 Processing
# 	- Lat: -25.513889
# 	- Lon: 31.224444
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 184 <= 312
# 185/319 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 185 <= 312
# 186/319 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 186 <= 312
# 187/319 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 187 <= 312
# 188/319 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 188 <= 312
# 189/319 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 189 <= 312
# 190/319 Processing
# 	- Lat: -33.818056
# 	- Lon: 19.694722
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 190 <= 312
# 191/319 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 191 <= 312
# 192/319 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 192 <= 312
# 193/319 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 24-11-2015
#
# 	Skipping... 193 <= 312
# 194/319 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 194 <= 312
# 195/319 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 195 <= 312
# 196/319 Processing
# 	- Lat: -25.436111
# 	- Lon: 31.982222
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 196 <= 312
# 197/319 Processing
# 	- Lat: -25.362222
# 	- Lon: 31.956667
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 197 <= 312
# 198/319 Processing
# 	- Lat: -25.398889
# 	- Lon: 31.610556
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 198 <= 312
# 199/319 Processing
# 	- Lat: -25.14944444
# 	- Lon: 31.94055556
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 199 <= 312
# 200/319 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 200 <= 312
# 201/319 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 201 <= 312
# 202/319 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 202 <= 312
# 203/319 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 203 <= 312
# 204/319 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 204 <= 312
# 205/319 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 205 <= 312
# 206/319 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 25-11-2015
#
# 	Skipping... 206 <= 312
# 207/319 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 26-11-2015
#
# 	Skipping... 207 <= 312
# 208/319 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 26-11-2015
#
# 	Skipping... 208 <= 312
# 209/319 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 26-11-2015
#
# 	Skipping... 209 <= 312
# 210/319 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 27-11-2015
#
# 	Skipping... 210 <= 312
# 211/319 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 30-11-2015
#
# 	Skipping... 211 <= 312
# 212/319 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 212 <= 312
# 213/319 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 213 <= 312
# 214/319 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 214 <= 312
# 215/319 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 215 <= 312
# 216/319 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 216 <= 312
# 217/319 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 217 <= 312
# 218/319 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 218 <= 312
# 219/319 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 219 <= 312
# 220/319 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 01-12-2015
#
# 	Skipping... 220 <= 312
# 221/319 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 221 <= 312
# 222/319 Processing
# 	- Lat: -25.73411
# 	- Lon: 27.21422
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 222 <= 312
# 223/319 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 223 <= 312
# 224/319 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 224 <= 312
# 225/319 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 225 <= 312
# 226/319 Processing
# 	- Lat: -31.436944
# 	- Lon: 20.474722
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 226 <= 312
# 227/319 Processing
# 	- Lat: -34.02861
# 	- Lon: 22.22222
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 227 <= 312
# 228/319 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 228 <= 312
# 229/319 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 229 <= 312
# 230/319 Processing
# 	- Lat: -34.005833
# 	- Lon: 22.351111
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 230 <= 312
# 231/319 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 02-12-2015
#
# 	Skipping... 231 <= 312
# 232/319 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 03-12-2015
#
# 	Skipping... 232 <= 312
# 233/319 Processing
# 	- Lat: -34.329722
# 	- Lon: 18.990278
# 	- Sample Date: 03-12-2015
#
# 	Skipping... 233 <= 312
# 234/319 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 03-12-2015
#
# 	Skipping... 234 <= 312
# 235/319 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 04-12-2015
#
# 	Skipping... 235 <= 312
# 236/319 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 04-12-2015
#
# 	Skipping... 236 <= 312
# 237/319 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 04-12-2015
#
# 	Skipping... 237 <= 312
# 238/319 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 05-12-2015
#
# 	Skipping... 238 <= 312
# 239/319 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 06-12-2015
#
# 	Skipping... 239 <= 312
# 240/319 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 07-12-2015
#
# 	Skipping... 240 <= 312
# 241/319 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 07-12-2015
#
# 	Skipping... 241 <= 312
# 242/319 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 07-12-2015
#
# 	Skipping... 242 <= 312
# 243/319 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 07-12-2015
#
# 	Skipping... 243 <= 312
# 244/319 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 07-12-2015
#
# 	Skipping... 244 <= 312
# 245/319 Processing
# 	- Lat: -29.140556
# 	- Lon: 31.391944
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 245 <= 312
# 246/319 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 246 <= 312
# 247/319 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 247 <= 312
# 248/319 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 248 <= 312
# 249/319 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 249 <= 312
# 250/319 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 250 <= 312
# 251/319 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 251 <= 312
# 252/319 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 252 <= 312
# 253/319 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 08-12-2015
#
# 	Skipping... 253 <= 312
# 254/319 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 254 <= 312
# 255/319 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 255 <= 312
# 256/319 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 256 <= 312
# 257/319 Processing
# 	- Lat: -22.91028
# 	- Lon: 29.61111
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 257 <= 312
# 258/319 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 258 <= 312
# 259/319 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 259 <= 312
# 260/319 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 260 <= 312
# 261/319 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 261 <= 312
# 262/319 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 09-12-2015
#
# 	Skipping... 262 <= 312
# 263/319 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 263 <= 312
# 264/319 Processing
# 	- Lat: -22.769722
# 	- Lon: 30.886944
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 264 <= 312
# 265/319 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 265 <= 312
# 266/319 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 266 <= 312
# 267/319 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 267 <= 312
# 268/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 12-01-2012
#
# 	Skipping... 268 <= 312
# 269/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 01-03-2012
#
# 	Skipping... 269 <= 312
# 270/319 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 270 <= 312
# 271/319 Processing
# 	- Lat: -30.679722
# 	- Lon: 26.7125
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 271 <= 312
# 272/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 19-06-2012
#
# 	Skipping... 272 <= 312
# 273/319 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 10-12-2015
#
# 	Skipping... 273 <= 312
# 274/319 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 11-12-2015
#
# 	Skipping... 274 <= 312
# 275/319 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 14-12-2015
#
# 	Skipping... 275 <= 312
# 276/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 18-01-2013
#
# 	Skipping... 276 <= 312
# 277/319 Processing
# 	- Lat: -26.619444
# 	- Lon: 27.980833
# 	- Sample Date: 14-12-2015
#
# 	Skipping... 277 <= 312
# 278/319 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 15-12-2015
#
# 	Skipping... 278 <= 312
# 279/319 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 15-12-2015
#
# 	Skipping... 279 <= 312
# 280/319 Processing
# 	- Lat: -26.510278
# 	- Lon: 28.351389
# 	- Sample Date: 15-12-2015
#
# 	Skipping... 280 <= 312
# 281/319 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 15-12-2015
#
# 	Skipping... 281 <= 312
# 282/319 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 282 <= 312
# 283/319 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 283 <= 312
# 284/319 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 284 <= 312
# 285/319 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 285 <= 312
# 286/319 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 286 <= 312
# 287/319 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 287 <= 312
# 288/319 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 288 <= 312
# 289/319 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 289 <= 312
# 290/319 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 290 <= 312
# 291/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 26-02-2015
#
# 	Skipping... 291 <= 312
# 292/319 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 292 <= 312
# 293/319 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 293 <= 312
# 294/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 21-05-2015
#
# 	Skipping... 294 <= 312
# 295/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 27-08-2015
#
# 	Skipping... 295 <= 312
# 296/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 29-10-2015
#
# 	Skipping... 296 <= 312
# 297/319 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 03-12-2015
#
# 	Skipping... 297 <= 312
# 298/319 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 16-12-2015
#
# 	Skipping... 298 <= 312
# 299/319 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 17-12-2015
#
# 	Skipping... 299 <= 312
# 300/319 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 17-12-2015
#
# 	Skipping... 300 <= 312
# 301/319 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 17-12-2015
#
# 	Skipping... 301 <= 312
# 302/319 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 18-12-2015
#
# 	Skipping... 302 <= 312
# 303/319 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 18-12-2015
#
# 	Skipping... 303 <= 312
# 304/319 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 21-12-2015
#
# 	Skipping... 304 <= 312
# 305/319 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 21-12-2015
#
# 	Skipping... 305 <= 312
# 306/319 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 21-12-2015
#
# 	Skipping... 306 <= 312
# 307/319 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 22-12-2015
#
# 	Skipping... 307 <= 312
# 308/319 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 22-12-2015
#
# 	Skipping... 308 <= 312
# 309/319 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 22-12-2015
#
# 	Skipping... 309 <= 312
# 310/319 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 22-12-2015
#
# 	Skipping... 310 <= 312
# 311/319 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 22-12-2015
#
# 	Skipping... 311 <= 312
# 312/319 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 22-12-2015
#
# 	Skipping... 312 <= 312
# 313/319 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 23-12-2015
#
# len_full_df = 313, count = 0
# 314/319 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 23-12-2015
#
# len_full_df = 314, count = 0
# 315/319 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 23-12-2015
#
# len_full_df = 315, count = 0
# 316/319 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 23-12-2015
#
# len_full_df = 316, count = 0
# 317/319 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 23-12-2015
#
# len_full_df = 317, count = 0
# 318/319 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 23-12-2015
#
# len_full_df = 318, count = 0
# 319/319 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 31-12-2015
#
# len_full_df = 319, count = 0
# Verifying Data Frame # Rows: 319

# %%
# session.sql(f"""
#     PUT file://{file_path}
#     'snow://workspace/USER$.PUBLIC."EY-AI-and-Data-Challenge-v2"/versions/live/'
#     AUTO_COMPRESS=FALSE
#     OVERWRITE=TRUE
# """).collect()
#
# print("File saved! Refresh the browser to see the files in the sidebar")
