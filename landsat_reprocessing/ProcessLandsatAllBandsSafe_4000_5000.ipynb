# %%
# !pip install uv
# !uv pip install  -r requirements.txt

# %%
import time
# import snowflake
# from snowflake.snowpark.context import get_active_session
# session = get_active_session()

import warnings
warnings.filterwarnings("ignore")

# Data manipulation and analysis
import numpy as np
import pandas as pd

# Planetary Computer tools for STAC API access and authentication
import pystac_client
import planetary_computer as pc
from odc.stac import stac_load
from pystac.extensions.eo import EOExtension as eo

from datetime import date
from tqdm import tqdm
import os
import time

# %%
# Setup
tqdm.pandas()

catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=pc.sign_inplace,
    )

bands_of_interest = {'red', 'blue', 'drad', 'emis', 'emsd', 'lwir', 'trad', 'urad', 'atran', 'cdist', 'green', 'nir08', 'swir16', 'swir22', 'atmos_opacity'}

def compute_Landsat_values(row):
    lat = row['Latitude']
    lon = row['Longitude']
    date = pd.to_datetime(row['Sample Date'], dayfirst=True, errors='coerce')


    # Buffer size for ~100m 
    bbox_size = 0.00089831  
    bbox = [
        lon - bbox_size / 2,
        lat - bbox_size / 2,
        lon + bbox_size / 2,
        lat + bbox_size / 2
    ]

    # Wider search range, we'll filter to nearest date later
    search = catalog.search(
        collections=["landsat-c2-l2"],
        bbox=bbox,
        datetime="2011-01-01/2015-12-31",
        query={"eo:cloud_cover": {"lt": 10}},
    )
    
    items = search.item_collection()

    if not items:
        # return pd.Series({
        #     "nir": np.nan
        #     , "green": np.nan
        #     , "swir16": np.nan
        #     , "swir22": np.nan
        #     , "red": np.nan
        #     , "blue": np.nan
        # })
        print("No items found")
        return pd.Series([np.nan] * len(bands_of_interest), index=bands_of_interest)


    # Convert sample date to UTC
    sample_date_utc = date.tz_localize("UTC") if date.tzinfo is None else date.tz_convert("UTC")

    # Pick the item closest to the sample date
    items = sorted(
        items,
        key=lambda x: abs(pd.to_datetime(x.properties["datetime"]).tz_convert("UTC") - sample_date_utc)
    )
    selected_item = pc.sign(items[0])

    # max_key_length = len(max(selected_item.assets, key=len))
    # for key, asset in selected_item.assets.items():
    #     print(f"{key.rjust(max_key_length)}: {asset.title}")

    # Load required bands
    # bands_of_interest = ["green", "nir08", "swir16", "swir22", "red", "blue"]
    bands_to_extract = [band for band in bands_of_interest if band in selected_item.assets.keys()]
    data = stac_load([selected_item], bands=bands_to_extract, bbox=bbox).isel(time=0)


    medians = []
    for band_name in bands_of_interest:
        if band_name in selected_item.assets.keys():
            band = data[band_name].astype("float")
            # Compute medians
            median_band = float(band.median(skipna=True).values)
            # Replace 0 with NaN
            median_band = median_band if median_band != 0 else np.nan
            medians.append(median_band)
        else:
            medians.append(np.nan)
    # print(pd.Series(medians, index=bands_of_interest))
    return pd.Series(medians, index=bands_of_interest)

# %%
Water_Quality_df=pd.read_csv('../water_quality_training_dataset.csv')
display(Water_Quality_df.head())
# Out:
#     Latitude  Longitude Sample Date  Total Alkalinity  Electrical Conductance  \
# 0 -28.760833  17.730278  02-01-2011           128.912                   555.0
# 1 -26.861111  28.884722  03-01-2011            74.720                   162.9
# 2 -26.450000  28.085833  03-01-2011            89.254                   573.0
# 3 -27.671111  27.236944  03-01-2011            82.000                   203.6
# 4 -27.356667  27.286389  03-01-2011            56.100                   145.1
#
#    Dissolved Reactive Phosphorus
# 0                           10.0
# 1                          163.0
# 2                           80.0
# 3                          101.0
# 4                          151.0

# %%
start_index = 4000
end_index = 5000
start_end_index_diff = end_index - start_index
to_process_df = Water_Quality_df[start_index:end_index]
print(to_process_df.shape)
# Out:
# (1000, 6)

# %%
len_full_df = 0
count=0
file_path = f"all_bands_extraction/landsat_features_training_all_bands_{start_index}_{end_index}.csv"
full_df = None
while len_full_df < start_end_index_diff and count < 20:

    file_path = f"all_bands_extraction/landsat_features_training_all_bands_{start_index}_{end_index}.csv"
    full_df = None
    if os.path.isfile(file_path):
        full_df = pd.read_csv(file_path)

    len_to_process_df = to_process_df.shape[0]

    for index, row in to_process_df.iterrows():
        try:
            lon = row["Longitude"]
            lat = row["Latitude"]
            sample_date = row["Sample Date"]
            print(f"{index - start_index + 1}/{len_to_process_df} Processing\n\t- Lat: {lat}\n\t- Lon: {lon}\n\t- Sample Date: {sample_date}\n")

            if full_df is not None and index - start_index + 1 <= full_df.shape[0]:
                len_full_df = full_df.shape[0]
                print(f"\tSkipping... {index - start_index + 1} <= {full_df.shape[0]}")
                continue

            new_row = compute_Landsat_values(row)

            row_df = row.to_frame().T
            row_df = row_df[["Latitude", "Longitude", "Sample Date"]]
            new_row_df = new_row.to_frame().T

            row_df = row_df.reset_index(drop=True)
            new_row_df = new_row_df.reset_index(drop=True)
            new_row_df = pd.concat([row_df, new_row_df], axis=1)

            # print(new_row)
            if full_df is None:
                full_df = new_row_df
                print(full_df)
            else:
                full_df = full_df.reset_index(drop=True)
                full_df = pd.concat([full_df, new_row_df], axis=0, ignore_index=True)

            len_full_df = full_df.shape[0]

            print(f"len_full_df = {len_full_df}, count = {count}")
        except Exception as e:
            full_df.to_csv(file_path, index = False, mode='w')
            print(f"Failed !!!\n{e}")
            count+=1
            break

full_df.to_csv(file_path, index = False, mode='w')
read_df = pd.read_csv(file_path)
print(f"Verifying Data Frame # Rows: {read_df.shape[0]}")
# Out:
# 1/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 29-05-2013
#
# 	Skipping... 1 <= 851
# 2/1000 Processing
# 	- Lat: -22.935
# 	- Lon: 28.004167
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 2 <= 851
# 3/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 3 <= 851
# 4/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 4 <= 851
# 5/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 5 <= 851
# 6/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 6 <= 851
# 7/1000 Processing
# 	- Lat: -29.042222
# 	- Lon: 24.6
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 7 <= 851
# 8/1000 Processing
# 	- Lat: -29.028629
# 	- Lon: 24.638389
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 8 <= 851
# 9/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 30-05-2013
#
# 	Skipping... 9 <= 851
# 10/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 31-05-2013
#
# 	Skipping... 10 <= 851
# 11/1000 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 03-06-2013
#
# 	Skipping... 11 <= 851
# 12/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 03-06-2013
#
# 	Skipping... 12 <= 851
# 13/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 03-06-2013
#
# 	Skipping... 13 <= 851
# 14/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 03-06-2013
#
# 	Skipping... 14 <= 851
# 15/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 15 <= 851
# 16/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 16 <= 851
# 17/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 17 <= 851
# 18/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 18 <= 851
# 19/1000 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 19 <= 851
# 20/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 20 <= 851
# 21/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 21 <= 851
# 22/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 22 <= 851
# 23/1000 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 23 <= 851
# 24/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 24 <= 851
# 25/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 04-06-2013
#
# 	Skipping... 25 <= 851
# 26/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 26 <= 851
# 27/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 27 <= 851
# 28/1000 Processing
# 	- Lat: -29.140556
# 	- Lon: 31.391944
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 28 <= 851
# 29/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 29 <= 851
# 30/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 30 <= 851
# 31/1000 Processing
# 	- Lat: -23.281
# 	- Lon: 30.54305556
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 31 <= 851
# 32/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 32 <= 851
# 33/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 33 <= 851
# 34/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 34 <= 851
# 35/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 35 <= 851
# 36/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 36 <= 851
# 37/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 37 <= 851
# 38/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 38 <= 851
# 39/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 39 <= 851
# 40/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 40 <= 851
# 41/1000 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 41 <= 851
# 42/1000 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 05-06-2013
#
# 	Skipping... 42 <= 851
# 43/1000 Processing
# 	- Lat: -22.769722
# 	- Lon: 30.886944
# 	- Sample Date: 06-06-2013
#
# 	Skipping... 43 <= 851
# 44/1000 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 06-06-2013
#
# 	Skipping... 44 <= 851
# 45/1000 Processing
# 	- Lat: -27.937778
# 	- Lon: 31.209444
# 	- Sample Date: 06-06-2013
#
# 	Skipping... 45 <= 851
# 46/1000 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 06-06-2013
#
# 	Skipping... 46 <= 851
# 47/1000 Processing
# 	- Lat: -31.394444
# 	- Lon: 20.947222
# 	- Sample Date: 06-06-2013
#
# 	Skipping... 47 <= 851
# 48/1000 Processing
# 	- Lat: -29.651389
# 	- Lon: 22.746389
# 	- Sample Date: 06-06-2013
#
# 	Skipping... 48 <= 851
# 49/1000 Processing
# 	- Lat: -34.005833
# 	- Lon: 22.351111
# 	- Sample Date: 06-06-2013
#
# 	Skipping... 49 <= 851
# 50/1000 Processing
# 	- Lat: -28.116667
# 	- Lon: 26.725278
# 	- Sample Date: 07-06-2013
#
# 	Skipping... 50 <= 851
# 51/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 07-06-2013
#
# 	Skipping... 51 <= 851
# 52/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 52 <= 851
# 53/1000 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 53 <= 851
# 54/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 54 <= 851
# 55/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 55 <= 851
# 56/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 56 <= 851
# 57/1000 Processing
# 	- Lat: -29.042222
# 	- Lon: 24.6
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 57 <= 851
# 58/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 58 <= 851
# 59/1000 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 10-06-2013
#
# 	Skipping... 59 <= 851
# 60/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 60 <= 851
# 61/1000 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 61 <= 851
# 62/1000 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 62 <= 851
# 63/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 63 <= 851
# 64/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 64 <= 851
# 65/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 65 <= 851
# 66/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 66 <= 851
# 67/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 67 <= 851
# 68/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 68 <= 851
# 69/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 69 <= 851
# 70/1000 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 70 <= 851
# 71/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 71 <= 851
# 72/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 72 <= 851
# 73/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 73 <= 851
# 74/1000 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 74 <= 851
# 75/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 11-06-2013
#
# 	Skipping... 75 <= 851
# 76/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 76 <= 851
# 77/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 77 <= 851
# 78/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 78 <= 851
# 79/1000 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 79 <= 851
# 80/1000 Processing
# 	- Lat: -27.802778
# 	- Lon: 28.768333
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 80 <= 851
# 81/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 81 <= 851
# 82/1000 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 82 <= 851
# 83/1000 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 83 <= 851
# 84/1000 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 84 <= 851
# 85/1000 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 85 <= 851
# 86/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 86 <= 851
# 87/1000 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 12-06-2013
#
# 	Skipping... 87 <= 851
# 88/1000 Processing
# 	- Lat: -28.44555556
# 	- Lon: 32.325
# 	- Sample Date: 05-09-2013
#
# 	Skipping... 88 <= 851
# 89/1000 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 14-06-2013
#
# 	Skipping... 89 <= 851
# 90/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 14-06-2013
#
# 	Skipping... 90 <= 851
# 91/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 14-06-2013
#
# 	Skipping... 91 <= 851
# 92/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 14-06-2013
#
# 	Skipping... 92 <= 851
# 93/1000 Processing
# 	- Lat: -28.96362
# 	- Lon: 19.15486
# 	- Sample Date: 15-06-2013
#
# 	Skipping... 93 <= 851
# 94/1000 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 17-06-2013
#
# 	Skipping... 94 <= 851
# 95/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 17-06-2013
#
# 	Skipping... 95 <= 851
# 96/1000 Processing
# 	- Lat: -31.860278
# 	- Lon: 18.6875
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 96 <= 851
# 97/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 97 <= 851
# 98/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 98 <= 851
# 99/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 99 <= 851
# 100/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 100 <= 851
# 101/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 101 <= 851
# 102/1000 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 102 <= 851
# 103/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 18-06-2013
#
# 	Skipping... 103 <= 851
# 104/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 104 <= 851
# 105/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 105 <= 851
# 106/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 106 <= 851
# 107/1000 Processing
# 	- Lat: -23.838611
# 	- Lon: 31.640833
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 107 <= 851
# 108/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 108 <= 851
# 109/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 109 <= 851
# 110/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 110 <= 851
# 111/1000 Processing
# 	- Lat: -32.601389
# 	- Lon: 18.750556
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 111 <= 851
# 112/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 19-06-2013
#
# 	Skipping... 112 <= 851
# 113/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 113 <= 851
# 114/1000 Processing
# 	- Lat: -28.7115
# 	- Lon: 24.07288889
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 114 <= 851
# 115/1000 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 115 <= 851
# 116/1000 Processing
# 	- Lat: -29.1825
# 	- Lon: 23.575556
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 116 <= 851
# 117/1000 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 117 <= 851
# 118/1000 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 118 <= 851
# 119/1000 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 119 <= 851
# 120/1000 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 20-06-2013
#
# 	Skipping... 120 <= 851
# 121/1000 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 21-06-2013
#
# 	Skipping... 121 <= 851
# 122/1000 Processing
# 	- Lat: -28.96362
# 	- Lon: 19.15486
# 	- Sample Date: 22-06-2013
#
# 	Skipping... 122 <= 851
# 123/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 22-06-2013
#
# 	Skipping... 123 <= 851
# 124/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 24-06-2013
#
# 	Skipping... 124 <= 851
# 125/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 24-06-2013
#
# 	Skipping... 125 <= 851
# 126/1000 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 24-06-2013
#
# 	Skipping... 126 <= 851
# 127/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 127 <= 851
# 128/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 128 <= 851
# 129/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 129 <= 851
# 130/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 130 <= 851
# 131/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 131 <= 851
# 132/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 132 <= 851
# 133/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 133 <= 851
# 134/1000 Processing
# 	- Lat: -29.042222
# 	- Lon: 24.6
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 134 <= 851
# 135/1000 Processing
# 	- Lat: -29.028629
# 	- Lon: 24.638389
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 135 <= 851
# 136/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 25-06-2013
#
# 	Skipping... 136 <= 851
# 137/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 137 <= 851
# 138/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 138 <= 851
# 139/1000 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 139 <= 851
# 140/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 140 <= 851
# 141/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 141 <= 851
# 142/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 142 <= 851
# 143/1000 Processing
# 	- Lat: -28.116667
# 	- Lon: 26.725278
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 143 <= 851
# 144/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 144 <= 851
# 145/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 26-06-2013
#
# 	Skipping... 145 <= 851
# 146/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 27-06-2013
#
# 	Skipping... 146 <= 851
# 147/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 27-06-2013
#
# 	Skipping... 147 <= 851
# 148/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 27-06-2013
#
# 	Skipping... 148 <= 851
# 149/1000 Processing
# 	- Lat: -28.760833
# 	- Lon: 17.730278
# 	- Sample Date: 28-06-2013
#
# 	Skipping... 149 <= 851
# 150/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 28-06-2013
#
# 	Skipping... 150 <= 851
# 151/1000 Processing
# 	- Lat: -28.96362
# 	- Lon: 19.15486
# 	- Sample Date: 29-06-2013
#
# 	Skipping... 151 <= 851
# 152/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 01-07-2013
#
# 	Skipping... 152 <= 851
# 153/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 01-07-2013
#
# 	Skipping... 153 <= 851
# 154/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 154 <= 851
# 155/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 155 <= 851
# 156/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 156 <= 851
# 157/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 157 <= 851
# 158/1000 Processing
# 	- Lat: -27.937778
# 	- Lon: 31.209444
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 158 <= 851
# 159/1000 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 159 <= 851
# 160/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 160 <= 851
# 161/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 161 <= 851
# 162/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 162 <= 851
# 163/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 163 <= 851
# 164/1000 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 164 <= 851
# 165/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 02-07-2013
#
# 	Skipping... 165 <= 851
# 166/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 166 <= 851
# 167/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 167 <= 851
# 168/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 168 <= 851
# 169/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 169 <= 851
# 170/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 170 <= 851
# 171/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 171 <= 851
# 172/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 172 <= 851
# 173/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 173 <= 851
# 174/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 174 <= 851
# 175/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 175 <= 851
# 176/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 176 <= 851
# 177/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 177 <= 851
# 178/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 178 <= 851
# 179/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 179 <= 851
# 180/1000 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 180 <= 851
# 181/1000 Processing
# 	- Lat: -33.870833
# 	- Lon: 20.003333
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 181 <= 851
# 182/1000 Processing
# 	- Lat: -25.57877778
# 	- Lon: 29.12747222
# 	- Sample Date: 03-07-2013
#
# 	Skipping... 182 <= 851
# 183/1000 Processing
# 	- Lat: -22.769722
# 	- Lon: 30.886944
# 	- Sample Date: 04-07-2013
#
# 	Skipping... 183 <= 851
# 184/1000 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 04-07-2013
#
# 	Skipping... 184 <= 851
# 185/1000 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 04-07-2013
#
# 	Skipping... 185 <= 851
# 186/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 04-07-2013
#
# 	Skipping... 186 <= 851
# 187/1000 Processing
# 	- Lat: -31.394444
# 	- Lon: 20.947222
# 	- Sample Date: 04-07-2013
#
# 	Skipping... 187 <= 851
# 188/1000 Processing
# 	- Lat: -34.329722
# 	- Lon: 18.990278
# 	- Sample Date: 04-07-2013
#
# 	Skipping... 188 <= 851
# 189/1000 Processing
# 	- Lat: -23.281
# 	- Lon: 30.54305556
# 	- Sample Date: 05-07-2013
#
# 	Skipping... 189 <= 851
# 190/1000 Processing
# 	- Lat: -27.937778
# 	- Lon: 31.209444
# 	- Sample Date: 05-07-2013
#
# 	Skipping... 190 <= 851
# 191/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 05-07-2013
#
# 	Skipping... 191 <= 851
# 192/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 05-07-2013
#
# 	Skipping... 192 <= 851
# 193/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 08-07-2013
#
# 	Skipping... 193 <= 851
# 194/1000 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 08-07-2013
#
# 	Skipping... 194 <= 851
# 195/1000 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 08-07-2013
#
# 	Skipping... 195 <= 851
# 196/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 08-07-2013
#
# 	Skipping... 196 <= 851
# 197/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 08-07-2013
#
# 	Skipping... 197 <= 851
# 198/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 08-07-2013
#
# 	Skipping... 198 <= 851
# 199/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 199 <= 851
# 200/1000 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 200 <= 851
# 201/1000 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 201 <= 851
# 202/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 202 <= 851
# 203/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 203 <= 851
# 204/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 204 <= 851
# 205/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 205 <= 851
# 206/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 206 <= 851
# 207/1000 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 207 <= 851
# 208/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 208 <= 851
# 209/1000 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 209 <= 851
# 210/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 210 <= 851
# 211/1000 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 211 <= 851
# 212/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 09-07-2013
#
# 	Skipping... 212 <= 851
# 213/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 213 <= 851
# 214/1000 Processing
# 	- Lat: -22.225556
# 	- Lon: 29.990556
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 214 <= 851
# 215/1000 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 215 <= 851
# 216/1000 Processing
# 	- Lat: -30.27402
# 	- Lon: 30.69602
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 216 <= 851
# 217/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 217 <= 851
# 218/1000 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 218 <= 851
# 219/1000 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 219 <= 851
# 220/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 220 <= 851
# 221/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 221 <= 851
# 222/1000 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 10-07-2013
#
# 	Skipping... 222 <= 851
# 223/1000 Processing
# 	- Lat: -24.282222
# 	- Lon: 28.090278
# 	- Sample Date: 11-07-2013
#
# 	Skipping... 223 <= 851
# 224/1000 Processing
# 	- Lat: -30.13573889
# 	- Lon: 30.67422222
# 	- Sample Date: 11-07-2013
#
# 	Skipping... 224 <= 851
# 225/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 11-07-2013
#
# 	Skipping... 225 <= 851
# 226/1000 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 11-07-2013
#
# 	Skipping... 226 <= 851
# 227/1000 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 11-07-2013
#
# 	Skipping... 227 <= 851
# 228/1000 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 11-07-2013
#
# 	Skipping... 228 <= 851
# 229/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 11-07-2013
#
# 	Skipping... 229 <= 851
# 230/1000 Processing
# 	- Lat: -30.830556
# 	- Lon: 26.921389
# 	- Sample Date: 12-07-2013
#
# 	Skipping... 230 <= 851
# 231/1000 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 12-07-2013
#
# 	Skipping... 231 <= 851
# 232/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 12-07-2013
#
# 	Skipping... 232 <= 851
# 233/1000 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 13-07-2013
#
# 	Skipping... 233 <= 851
# 234/1000 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 15-07-2013
#
# 	Skipping... 234 <= 851
# 235/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 15-07-2013
#
# 	Skipping... 235 <= 851
# 236/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 15-07-2013
#
# 	Skipping... 236 <= 851
# 237/1000 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 15-07-2013
#
# 	Skipping... 237 <= 851
# 238/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 238 <= 851
# 239/1000 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 239 <= 851
# 240/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 240 <= 851
# 241/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 241 <= 851
# 242/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 242 <= 851
# 243/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 243 <= 851
# 244/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 244 <= 851
# 245/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 245 <= 851
# 246/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 246 <= 851
# 247/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 247 <= 851
# 248/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 248 <= 851
# 249/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 249 <= 851
# 250/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 250 <= 851
# 251/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 16-07-2013
#
# 	Skipping... 251 <= 851
# 252/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 252 <= 851
# 253/1000 Processing
# 	- Lat: -22.91028
# 	- Lon: 29.61111
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 253 <= 851
# 254/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 254 <= 851
# 255/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 255 <= 851
# 256/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 256 <= 851
# 257/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 257 <= 851
# 258/1000 Processing
# 	- Lat: -28.768056
# 	- Lon: 20.720556
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 258 <= 851
# 259/1000 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 259 <= 851
# 260/1000 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 17-07-2013
#
# 	Skipping... 260 <= 851
# 261/1000 Processing
# 	- Lat: -22.935
# 	- Lon: 28.004167
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 261 <= 851
# 262/1000 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 262 <= 851
# 263/1000 Processing
# 	- Lat: -23.23572222
# 	- Lon: 27.717
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 263 <= 851
# 264/1000 Processing
# 	- Lat: -26.905
# 	- Lon: 32.324722
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 264 <= 851
# 265/1000 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 265 <= 851
# 266/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 266 <= 851
# 267/1000 Processing
# 	- Lat: -27.935
# 	- Lon: 26.126667
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 267 <= 851
# 268/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 18-07-2013
#
# 	Skipping... 268 <= 851
# 269/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 19-07-2013
#
# 	Skipping... 269 <= 851
# 270/1000 Processing
# 	- Lat: -28.96362
# 	- Lon: 19.15486
# 	- Sample Date: 20-07-2013
#
# 	Skipping... 270 <= 851
# 271/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 22-07-2013
#
# 	Skipping... 271 <= 851
# 272/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 22-07-2013
#
# 	Skipping... 272 <= 851
# 273/1000 Processing
# 	- Lat: -31.860278
# 	- Lon: 18.6875
# 	- Sample Date: 23-07-2013
#
# 	Skipping... 273 <= 851
# 274/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 23-07-2013
#
# 	Skipping... 274 <= 851
# 275/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 23-07-2013
#
# 	Skipping... 275 <= 851
# 276/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 23-07-2013
#
# 	Skipping... 276 <= 851
# 277/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 23-07-2013
#
# 	Skipping... 277 <= 851
# 278/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 23-07-2013
#
# 	Skipping... 278 <= 851
# 279/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 279 <= 851
# 280/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 280 <= 851
# 281/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 281 <= 851
# 282/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 282 <= 851
# 283/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 283 <= 851
# 284/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 284 <= 851
# 285/1000 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 285 <= 851
# 286/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 24-07-2013
#
# 	Skipping... 286 <= 851
# 287/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 287 <= 851
# 288/1000 Processing
# 	- Lat: -23.838611
# 	- Lon: 31.640833
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 288 <= 851
# 289/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 289 <= 851
# 290/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 290 <= 851
# 291/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 291 <= 851
# 292/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 292 <= 851
# 293/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 293 <= 851
# 294/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 294 <= 851
# 295/1000 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 25-07-2013
#
# 	Skipping... 295 <= 851
# 296/1000 Processing
# 	- Lat: -29.140556
# 	- Lon: 31.391944
# 	- Sample Date: 29-07-2013
#
# 	Skipping... 296 <= 851
# 297/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 297 <= 851
# 298/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 298 <= 851
# 299/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 299 <= 851
# 300/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 300 <= 851
# 301/1000 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 301 <= 851
# 302/1000 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 302 <= 851
# 303/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 303 <= 851
# 304/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 304 <= 851
# 305/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 305 <= 851
# 306/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 306 <= 851
# 307/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 307 <= 851
# 308/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 308 <= 851
# 309/1000 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 309 <= 851
# 310/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 310 <= 851
# 311/1000 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 30-07-2013
#
# 	Skipping... 311 <= 851
# 312/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 31-07-2013
#
# 	Skipping... 312 <= 851
# 313/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 31-07-2013
#
# 	Skipping... 313 <= 851
# 314/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 31-07-2013
#
# 	Skipping... 314 <= 851
# 315/1000 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 31-07-2013
#
# 	Skipping... 315 <= 851
# 316/1000 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 31-07-2013
#
# 	Skipping... 316 <= 851
# 317/1000 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 31-07-2013
#
# 	Skipping... 317 <= 851
# 318/1000 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 01-08-2013
#
# 	Skipping... 318 <= 851
# 319/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 01-08-2013
#
# 	Skipping... 319 <= 851
# 320/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 01-08-2013
#
# 	Skipping... 320 <= 851
# 321/1000 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 01-08-2013
#
# 	Skipping... 321 <= 851
# 322/1000 Processing
# 	- Lat: -29.651389
# 	- Lon: 22.746389
# 	- Sample Date: 01-08-2013
#
# 	Skipping... 322 <= 851
# 323/1000 Processing
# 	- Lat: -29.1825
# 	- Lon: 23.575556
# 	- Sample Date: 01-08-2013
#
# 	Skipping... 323 <= 851
# 324/1000 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 01-08-2013
#
# 	Skipping... 324 <= 851
# 325/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 02-08-2013
#
# 	Skipping... 325 <= 851
# 326/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 03-08-2013
#
# 	Skipping... 326 <= 851
# 327/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 05-08-2013
#
# 	Skipping... 327 <= 851
# 328/1000 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 05-08-2013
#
# 	Skipping... 328 <= 851
# 329/1000 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 05-08-2013
#
# 	Skipping... 329 <= 851
# 330/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 05-08-2013
#
# 	Skipping... 330 <= 851
# 331/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 05-08-2013
#
# 	Skipping... 331 <= 851
# 332/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 05-08-2013
#
# 	Skipping... 332 <= 851
# 333/1000 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 05-08-2013
#
# 	Skipping... 333 <= 851
# 334/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 06-08-2013
#
# 	Skipping... 334 <= 851
# 335/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 06-08-2013
#
# 	Skipping... 335 <= 851
# 336/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 06-08-2013
#
# 	Skipping... 336 <= 851
# 337/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 06-08-2013
#
# 	Skipping... 337 <= 851
# 338/1000 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 06-08-2013
#
# 	Skipping... 338 <= 851
# 339/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 06-08-2013
#
# 	Skipping... 339 <= 851
# 340/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 340 <= 851
# 341/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 341 <= 851
# 342/1000 Processing
# 	- Lat: -30.830556
# 	- Lon: 26.921389
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 342 <= 851
# 343/1000 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 343 <= 851
# 344/1000 Processing
# 	- Lat: -27.02314
# 	- Lon: 28.59389
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 344 <= 851
# 345/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 345 <= 851
# 346/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 346 <= 851
# 347/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 347 <= 851
# 348/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 348 <= 851
# 349/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 349 <= 851
# 350/1000 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 350 <= 851
# 351/1000 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 351 <= 851
# 352/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 07-08-2013
#
# 	Skipping... 352 <= 851
# 353/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 353 <= 851
# 354/1000 Processing
# 	- Lat: -28.44555556
# 	- Lon: 32.325
# 	- Sample Date: 01-10-2013
#
# 	Skipping... 354 <= 851
# 355/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 355 <= 851
# 356/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 356 <= 851
# 357/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 357 <= 851
# 358/1000 Processing
# 	- Lat: -27.573056
# 	- Lon: 24.746389
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 358 <= 851
# 359/1000 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 359 <= 851
# 360/1000 Processing
# 	- Lat: -30.679722
# 	- Lon: 26.7125
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 360 <= 851
# 361/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 361 <= 851
# 362/1000 Processing
# 	- Lat: -25.57877778
# 	- Lon: 29.12747222
# 	- Sample Date: 08-08-2013
#
# 	Skipping... 362 <= 851
# 363/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 09-08-2013
#
# 	Skipping... 363 <= 851
# 364/1000 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 12-08-2013
#
# 	Skipping... 364 <= 851
# 365/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 12-08-2013
#
# 	Skipping... 365 <= 851
# 366/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 12-08-2013
#
# 	Skipping... 366 <= 851
# 367/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 12-08-2013
#
# 	Skipping... 367 <= 851
# 368/1000 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 12-08-2013
#
# 	Skipping... 368 <= 851
# 369/1000 Processing
# 	- Lat: -28.760833
# 	- Lon: 17.730278
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 369 <= 851
# 370/1000 Processing
# 	- Lat: -22.225556
# 	- Lon: 29.990556
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 370 <= 851
# 371/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 371 <= 851
# 372/1000 Processing
# 	- Lat: -24.39619444
# 	- Lon: 27.08983333
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 372 <= 851
# 373/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 373 <= 851
# 374/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 374 <= 851
# 375/1000 Processing
# 	- Lat: -23.281
# 	- Lon: 30.54305556
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 375 <= 851
# 376/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 376 <= 851
# 377/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 377 <= 851
# 378/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 378 <= 851
# 379/1000 Processing
# 	- Lat: -29.1825
# 	- Lon: 23.575556
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 379 <= 851
# 380/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 380 <= 851
# 381/1000 Processing
# 	- Lat: -34.02861
# 	- Lon: 22.22222
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 381 <= 851
# 382/1000 Processing
# 	- Lat: -31.5653
# 	- Lon: 18.3306
# 	- Sample Date: 13-08-2013
#
# 	Skipping... 382 <= 851
# 383/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 383 <= 851
# 384/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 384 <= 851
# 385/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 385 <= 851
# 386/1000 Processing
# 	- Lat: -24.183889
# 	- Lon: 30.823889
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 386 <= 851
# 387/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 387 <= 851
# 388/1000 Processing
# 	- Lat: -22.769722
# 	- Lon: 30.886944
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 388 <= 851
# 389/1000 Processing
# 	- Lat: -23.838611
# 	- Lon: 31.640833
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 389 <= 851
# 390/1000 Processing
# 	- Lat: -24.058889
# 	- Lon: 31.237222
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 390 <= 851
# 391/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 391 <= 851
# 392/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 392 <= 851
# 393/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 393 <= 851
# 394/1000 Processing
# 	- Lat: -27.38972222
# 	- Lon: 26.46388889
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 394 <= 851
# 395/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 395 <= 851
# 396/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 396 <= 851
# 397/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 397 <= 851
# 398/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 398 <= 851
# 399/1000 Processing
# 	- Lat: -28.768056
# 	- Lon: 20.720556
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 399 <= 851
# 400/1000 Processing
# 	- Lat: -34.092222
# 	- Lon: 21.295278
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 400 <= 851
# 401/1000 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 14-08-2013
#
# 	Skipping... 401 <= 851
# 402/1000 Processing
# 	- Lat: -26.905
# 	- Lon: 32.324722
# 	- Sample Date: 15-08-2013
#
# 	Skipping... 402 <= 851
# 403/1000 Processing
# 	- Lat: -27.602222
# 	- Lon: 29.942778
# 	- Sample Date: 15-08-2013
#
# 	Skipping... 403 <= 851
# 404/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 15-08-2013
#
# 	Skipping... 404 <= 851
# 405/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 15-08-2013
#
# 	Skipping... 405 <= 851
# 406/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 15-08-2013
#
# 	Skipping... 406 <= 851
# 407/1000 Processing
# 	- Lat: -24.679167
# 	- Lon: 30.8025
# 	- Sample Date: 16-08-2013
#
# 	Skipping... 407 <= 851
# 408/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 16-08-2013
#
# 	Skipping... 408 <= 851
# 409/1000 Processing
# 	- Lat: -25.447222
# 	- Lon: 30.711667
# 	- Sample Date: 18-08-2013
#
# 	Skipping... 409 <= 851
# 410/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 19-08-2013
#
# 	Skipping... 410 <= 851
# 411/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 19-08-2013
#
# 	Skipping... 411 <= 851
# 412/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 19-08-2013
#
# 	Skipping... 412 <= 851
# 413/1000 Processing
# 	- Lat: -31.860278
# 	- Lon: 18.6875
# 	- Sample Date: 20-08-2013
#
# 	Skipping... 413 <= 851
# 414/1000 Processing
# 	- Lat: -22.91028
# 	- Lon: 29.61111
# 	- Sample Date: 20-08-2013
#
# 	Skipping... 414 <= 851
# 415/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 20-08-2013
#
# 	Skipping... 415 <= 851
# 416/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 416 <= 851
# 417/1000 Processing
# 	- Lat: -22.935
# 	- Lon: 28.004167
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 417 <= 851
# 418/1000 Processing
# 	- Lat: -26.03611
# 	- Lon: 30.99778
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 418 <= 851
# 419/1000 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 419 <= 851
# 420/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 420 <= 851
# 421/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 421 <= 851
# 422/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 422 <= 851
# 423/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 21-08-2013
#
# 	Skipping... 423 <= 851
# 424/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 22-08-2013
#
# 	Skipping... 424 <= 851
# 425/1000 Processing
# 	- Lat: -24.282222
# 	- Lon: 28.090278
# 	- Sample Date: 22-08-2013
#
# 	Skipping... 425 <= 851
# 426/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 22-08-2013
#
# 	Skipping... 426 <= 851
# 427/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 22-08-2013
#
# 	Skipping... 427 <= 851
# 428/1000 Processing
# 	- Lat: -28.116667
# 	- Lon: 26.725278
# 	- Sample Date: 22-08-2013
#
# 	Skipping... 428 <= 851
# 429/1000 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 22-08-2013
#
# 	Skipping... 429 <= 851
# 430/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 23-08-2013
#
# 	Skipping... 430 <= 851
# 431/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 23-08-2013
#
# 	Skipping... 431 <= 851
# 432/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 23-08-2013
#
# 	Skipping... 432 <= 851
# 433/1000 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 24-08-2013
#
# 	Skipping... 433 <= 851
# 434/1000 Processing
# 	- Lat: -24.99328
# 	- Lon: 30.81444
# 	- Sample Date: 26-08-2013
#
# 	Skipping... 434 <= 851
# 435/1000 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 26-08-2013
#
# 	Skipping... 435 <= 851
# 436/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 26-08-2013
#
# 	Skipping... 436 <= 851
# 437/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 26-08-2013
#
# 	Skipping... 437 <= 851
# 438/1000 Processing
# 	- Lat: -33.818056
# 	- Lon: 19.694722
# 	- Sample Date: 26-08-2013
#
# 	Skipping... 438 <= 851
# 439/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 27-08-2013
#
# 	Skipping... 439 <= 851
# 440/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 27-08-2013
#
# 	Skipping... 440 <= 851
# 441/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 27-08-2013
#
# 	Skipping... 441 <= 851
# 442/1000 Processing
# 	- Lat: -22.43772222
# 	- Lon: 31.07805556
# 	- Sample Date: 27-08-2013
#
# 	Skipping... 442 <= 851
# 443/1000 Processing
# 	- Lat: -25.681111
# 	- Lon: 31.783333
# 	- Sample Date: 27-08-2013
#
# 	Skipping... 443 <= 851
# 444/1000 Processing
# 	- Lat: -25.67386
# 	- Lon: 31.57527
# 	- Sample Date: 27-08-2013
#
# 	Skipping... 444 <= 851
# ...
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 856 <= 943
# 857/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 857 <= 943
# 858/1000 Processing
# 	- Lat: -22.43772222
# 	- Lon: 31.07805556
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 858 <= 943
# 859/1000 Processing
# 	- Lat: -28.75
# 	- Lon: 30.442778
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 859 <= 943
# 860/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 30.629722
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 860 <= 943
# 861/1000 Processing
# 	- Lat: -28.141944
# 	- Lon: 26.417778
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 861 <= 943
# 862/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 862 <= 943
# 863/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 863 <= 943
# 864/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 864 <= 943
# 865/1000 Processing
# 	- Lat: -34.02861
# 	- Lon: 22.22222
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 865 <= 943
# 866/1000 Processing
# 	- Lat: -34.005833
# 	- Lon: 22.351111
# 	- Sample Date: 13-11-2013
#
# 	Skipping... 866 <= 943
# 867/1000 Processing
# 	- Lat: -23.658056
# 	- Lon: 31.05
# 	- Sample Date: 14-11-2013
#
# 	Skipping... 867 <= 943
# 868/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 14-11-2013
#
# 	Skipping... 868 <= 943
# 869/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 14-11-2013
#
# 	Skipping... 869 <= 943
# 870/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 14-11-2013
#
# 	Skipping... 870 <= 943
# 871/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 14-11-2013
#
# 	Skipping... 871 <= 943
# 872/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 14-11-2013
#
# 	Skipping... 872 <= 943
# 873/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 14-11-2013
#
# 	Skipping... 873 <= 943
# 874/1000 Processing
# 	- Lat: -34.031944
# 	- Lon: 22.053333
# 	- Sample Date: 15-11-2013
#
# 	Skipping... 874 <= 943
# 875/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 15-11-2013
#
# 	Skipping... 875 <= 943
# 876/1000 Processing
# 	- Lat: -24.925278
# 	- Lon: 29.324444
# 	- Sample Date: 18-11-2013
#
# 	Skipping... 876 <= 943
# 877/1000 Processing
# 	- Lat: -29.380556
# 	- Lon: 30.2775
# 	- Sample Date: 18-11-2013
#
# 	Skipping... 877 <= 943
# 878/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 18-11-2013
#
# 	Skipping... 878 <= 943
# 879/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 18-11-2013
#
# 	Skipping... 879 <= 943
# 880/1000 Processing
# 	- Lat: -33.870833
# 	- Lon: 20.003333
# 	- Sample Date: 18-11-2013
#
# 	Skipping... 880 <= 943
# 881/1000 Processing
# 	- Lat: -33.818056
# 	- Lon: 19.694722
# 	- Sample Date: 18-11-2013
#
# 	Skipping... 881 <= 943
# 882/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 882 <= 943
# 883/1000 Processing
# 	- Lat: -34.065833
# 	- Lon: 20.404167
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 883 <= 943
# 884/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 884 <= 943
# 885/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 885 <= 943
# 886/1000 Processing
# 	- Lat: -28.747778
# 	- Lon: 31.745833
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 886 <= 943
# 887/1000 Processing
# 	- Lat: -27.169444
# 	- Lon: 29.233889
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 887 <= 943
# 888/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 888 <= 943
# 889/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 889 <= 943
# 890/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 890 <= 943
# 891/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 891 <= 943
# 892/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 892 <= 943
# 893/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 893 <= 943
# 894/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 894 <= 943
# 895/1000 Processing
# 	- Lat: -27.671111
# 	- Lon: 27.236944
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 895 <= 943
# 896/1000 Processing
# 	- Lat: -31.396
# 	- Lon: 29.2651
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 896 <= 943
# 897/1000 Processing
# 	- Lat: -31.554722
# 	- Lon: 29.245556
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 897 <= 943
# 898/1000 Processing
# 	- Lat: -34.075556
# 	- Lon: 20.145556
# 	- Sample Date: 19-11-2013
#
# 	Skipping... 898 <= 943
# 899/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 899 <= 943
# 900/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 900 <= 943
# 901/1000 Processing
# 	- Lat: -28.801278
# 	- Lon: 31.955389
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 901 <= 943
# 902/1000 Processing
# 	- Lat: -27.937778
# 	- Lon: 31.209444
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 902 <= 943
# 903/1000 Processing
# 	- Lat: -28.404444
# 	- Lon: 30.013056
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 903 <= 943
# 904/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 904 <= 943
# 905/1000 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 905 <= 943
# 906/1000 Processing
# 	- Lat: -30.568333
# 	- Lon: 29.422778
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 906 <= 943
# 907/1000 Processing
# 	- Lat: -31.104278
# 	- Lon: 29.399722
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 907 <= 943
# 908/1000 Processing
# 	- Lat: -34.250556
# 	- Lon: 20.9925
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 908 <= 943
# 909/1000 Processing
# 	- Lat: -34.329722
# 	- Lon: 18.990278
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 909 <= 943
# 910/1000 Processing
# 	- Lat: -25.57877778
# 	- Lon: 29.12747222
# 	- Sample Date: 20-11-2013
#
# 	Skipping... 910 <= 943
# 911/1000 Processing
# 	- Lat: -27.5275
# 	- Lon: 30.858056
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 911 <= 943
# 912/1000 Processing
# 	- Lat: -28.116667
# 	- Lon: 26.725278
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 912 <= 943
# 913/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 913 <= 943
# 914/1000 Processing
# 	- Lat: -30.86013889
# 	- Lon: 29.07125
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 914 <= 943
# 915/1000 Processing
# 	- Lat: -30.570833
# 	- Lon: 29.150556
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 915 <= 943
# 916/1000 Processing
# 	- Lat: -30.77586667
# 	- Lon: 29.03221667
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 916 <= 943
# 917/1000 Processing
# 	- Lat: -34.405833
# 	- Lon: 19.600556
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 917 <= 943
# 918/1000 Processing
# 	- Lat: -33.897778
# 	- Lon: 20.012778
# 	- Sample Date: 21-11-2013
#
# 	Skipping... 918 <= 943
# 919/1000 Processing
# 	- Lat: -27.902778
# 	- Lon: 24.615556
# 	- Sample Date: 22-11-2013
#
# 	Skipping... 919 <= 943
# 920/1000 Processing
# 	- Lat: -31.031389
# 	- Lon: 28.883333
# 	- Sample Date: 22-11-2013
#
# 	Skipping... 920 <= 943
# 921/1000 Processing
# 	- Lat: -28.058889
# 	- Lon: 30.373611
# 	- Sample Date: 22-11-2013
#
# 	Skipping... 921 <= 943
# 922/1000 Processing
# 	- Lat: -25.99136
# 	- Lon: 27.84208
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 922 <= 943
# 923/1000 Processing
# 	- Lat: -29.7775
# 	- Lon: 29.470833
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 923 <= 943
# 924/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 924 <= 943
# 925/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 925 <= 943
# 926/1000 Processing
# 	- Lat: -29.042222
# 	- Lon: 24.6
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 926 <= 943
# 927/1000 Processing
# 	- Lat: -33.38056
# 	- Lon: 19.30167
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 927 <= 943
# 928/1000 Processing
# 	- Lat: -32.502778
# 	- Lon: 19.535833
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 928 <= 943
# 929/1000 Processing
# 	- Lat: -28.338333
# 	- Lon: 31.373611
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 929 <= 943
# 930/1000 Processing
# 	- Lat: -28.068333
# 	- Lon: 31.55
# 	- Sample Date: 25-11-2013
#
# 	Skipping... 930 <= 943
# 931/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 26-07-2011
#
# 	Skipping... 931 <= 943
# 932/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 23-08-2011
#
# 	Skipping... 932 <= 943
# 933/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 30-08-2011
#
# 	Skipping... 933 <= 943
# 934/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 21-09-2011
#
# 	Skipping... 934 <= 943
# 935/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 29-09-2011
#
# 	Skipping... 935 <= 943
# 936/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 17-11-2011
#
# 	Skipping... 936 <= 943
# 937/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 26-11-2013
#
# 	Skipping... 937 <= 943
# 938/1000 Processing
# 	- Lat: -31.860278
# 	- Lon: 18.6875
# 	- Sample Date: 26-11-2013
#
# 	Skipping... 938 <= 943
# 939/1000 Processing
# 	- Lat: -25.73411
# 	- Lon: 27.21422
# 	- Sample Date: 26-11-2013
#
# 	Skipping... 939 <= 943
# 940/1000 Processing
# 	- Lat: -30.733889
# 	- Lon: 29.828333
# 	- Sample Date: 26-11-2013
#
# 	Skipping... 940 <= 943
# 941/1000 Processing
# 	- Lat: -29.987778
# 	- Lon: 29.851667
# 	- Sample Date: 26-11-2013
#
# 	Skipping... 941 <= 943
# 942/1000 Processing
# 	- Lat: -27.00222
# 	- Lon: 28.76528
# 	- Sample Date: 26-11-2013
#
# 	Skipping... 942 <= 943
# 943/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 07-06-2012
#
# 	Skipping... 943 <= 943
# 944/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 26-11-2013
#
# len_full_df = 944, count = 2
# 945/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 26-11-2013
#
# len_full_df = 945, count = 2
# 946/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 26-11-2013
#
# len_full_df = 946, count = 2
# 947/1000 Processing
# 	- Lat: -29.160278
# 	- Lon: 26.573333
# 	- Sample Date: 26-11-2013
#
# len_full_df = 947, count = 2
# 948/1000 Processing
# 	- Lat: -29.028629
# 	- Lon: 24.638389
# 	- Sample Date: 26-11-2013
#
# len_full_df = 948, count = 2
# 949/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 26-11-2013
#
# len_full_df = 949, count = 2
# 950/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 17-07-2012
#
# len_full_df = 950, count = 2
# 951/1000 Processing
# 	- Lat: -33.501667
# 	- Lon: 21.624167
# 	- Sample Date: 26-11-2013
#
# len_full_df = 951, count = 2
# 952/1000 Processing
# 	- Lat: -32.595833
# 	- Lon: 19.009444
# 	- Sample Date: 26-11-2013
#
# len_full_df = 952, count = 2
# 953/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 17-09-2012
#
# len_full_df = 953, count = 2
# 954/1000 Processing
# 	- Lat: -25.45963889
# 	- Lon: 28.26430556
# 	- Sample Date: 26-11-2013
#
# len_full_df = 954, count = 2
# 955/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 27-11-2013
#
# len_full_df = 955, count = 2
# 956/1000 Processing
# 	- Lat: -25.81048333
# 	- Lon: 27.90955222
# 	- Sample Date: 27-11-2013
#
# len_full_df = 956, count = 2
# 957/1000 Processing
# 	- Lat: -24.670833
# 	- Lon: 28.560833
# 	- Sample Date: 27-11-2013
#
# len_full_df = 957, count = 2
# 958/1000 Processing
# 	- Lat: -30.398056
# 	- Lon: 30.601944
# 	- Sample Date: 27-11-2013
#
# len_full_df = 958, count = 2
# 959/1000 Processing
# 	- Lat: -26.861111
# 	- Lon: 28.884722
# 	- Sample Date: 27-11-2013
#
# len_full_df = 959, count = 2
# 960/1000 Processing
# 	- Lat: -29.033333
# 	- Lon: 23.983333
# 	- Sample Date: 27-11-2013
#
# len_full_df = 960, count = 2
# 961/1000 Processing
# 	- Lat: -28.69485
# 	- Lon: 28.23487
# 	- Sample Date: 27-11-2013
#
# len_full_df = 961, count = 2
# 962/1000 Processing
# 	- Lat: -29.615556
# 	- Lon: 27.065278
# 	- Sample Date: 27-11-2013
#
# len_full_df = 962, count = 2
# 963/1000 Processing
# 	- Lat: -28.883333
# 	- Lon: 27.89
# 	- Sample Date: 27-11-2013
#
# len_full_df = 963, count = 2
# 964/1000 Processing
# 	- Lat: -33.7075
# 	- Lon: 18.97444444
# 	- Sample Date: 27-11-2013
#
# len_full_df = 964, count = 2
# 965/1000 Processing
# 	- Lat: -32.94583
# 	- Lon: 18.33667
# 	- Sample Date: 27-11-2013
#
# len_full_df = 965, count = 2
# 966/1000 Processing
# 	- Lat: -24.282222
# 	- Lon: 28.090278
# 	- Sample Date: 28-11-2013
#
# len_full_df = 966, count = 2
# 967/1000 Processing
# 	- Lat: -30.13573889
# 	- Lon: 30.67422222
# 	- Sample Date: 28-11-2013
#
# len_full_df = 967, count = 2
# 968/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 18-07-2013
#
# len_full_df = 968, count = 2
# 969/1000 Processing
# 	- Lat: -33.31388889
# 	- Lon: 19.07472222
# 	- Sample Date: 28-11-2013
#
# len_full_df = 969, count = 2
# 970/1000 Processing
# 	- Lat: -33.13083
# 	- Lon: 18.86278
# 	- Sample Date: 28-11-2013
#
# len_full_df = 970, count = 2
# 971/1000 Processing
# 	- Lat: -29.744167
# 	- Lon: 29.905833
# 	- Sample Date: 29-11-2013
#
# len_full_df = 971, count = 2
# 972/1000 Processing
# 	- Lat: -29.803611
# 	- Lon: 30.516111
# 	- Sample Date: 29-11-2013
#
# len_full_df = 972, count = 2
# 973/1000 Processing
# 	- Lat: -26.73806
# 	- Lon: 27.59194
# 	- Sample Date: 01-12-2013
#
# len_full_df = 973, count = 2
# 974/1000 Processing
# 	- Lat: -28.735556
# 	- Lon: 29.820556
# 	- Sample Date: 02-12-2013
#
# len_full_df = 974, count = 2
# 975/1000 Processing
# 	- Lat: -26.45
# 	- Lon: 28.085833
# 	- Sample Date: 02-12-2013
#
# len_full_df = 975, count = 2
# 976/1000 Processing
# 	- Lat: -25.127778
# 	- Lon: 27.628889
# 	- Sample Date: 03-12-2013
#
# len_full_df = 976, count = 2
# 977/1000 Processing
# 	- Lat: -24.69514
# 	- Lon: 27.40906
# 	- Sample Date: 03-12-2013
#
# len_full_df = 977, count = 2
# 978/1000 Processing
# 	- Lat: -27.273889
# 	- Lon: 28.49
# 	- Sample Date: 03-12-2013
#
# len_full_df = 978, count = 2
# 979/1000 Processing
# 	- Lat: -27.4275
# 	- Lon: 28.525833
# 	- Sample Date: 03-12-2013
#
# len_full_df = 979, count = 2
# 980/1000 Processing
# 	- Lat: -27.3
# 	- Lon: 28.586944
# 	- Sample Date: 03-12-2013
#
# len_full_df = 980, count = 2
# 981/1000 Processing
# 	- Lat: -27.398611
# 	- Lon: 26.614722
# 	- Sample Date: 03-12-2013
#
# len_full_df = 981, count = 2
# 982/1000 Processing
# 	- Lat: -30.160091
# 	- Lon: 27.40124
# 	- Sample Date: 03-12-2013
#
# len_full_df = 982, count = 2
# 983/1000 Processing
# 	- Lat: -30.336111
# 	- Lon: 27.359444
# 	- Sample Date: 03-12-2013
#
# len_full_df = 983, count = 2
# 984/1000 Processing
# 	- Lat: -33.08883333
# 	- Lon: 19.21878333
# 	- Sample Date: 03-12-2013
#
# len_full_df = 984, count = 2
# 985/1000 Processing
# 	- Lat: -27.4
# 	- Lon: 26.624722
# 	- Sample Date: 03-12-2013
#
# len_full_df = 985, count = 2
# 986/1000 Processing
# 	- Lat: -29.161667
# 	- Lon: 23.696389
# 	- Sample Date: 04-12-2013
#
# len_full_df = 986, count = 2
# 987/1000 Processing
# 	- Lat: -27.01011111
# 	- Lon: 26.69808333
# 	- Sample Date: 04-12-2013
#
# len_full_df = 987, count = 2
# 988/1000 Processing
# 	- Lat: -29.641944
# 	- Lon: 30.6875
# 	- Sample Date: 04-12-2013
#
# len_full_df = 988, count = 2
# 989/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 19-05-2014
#
# len_full_df = 989, count = 2
# 990/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 03-06-2014
#
# len_full_df = 990, count = 2
# 991/1000 Processing
# 	- Lat: -25.20639
# 	- Lon: 27.558
# 	- Sample Date: 04-12-2013
#
# len_full_df = 991, count = 2
# 992/1000 Processing
# 	- Lat: -27.363611
# 	- Lon: 31.783333
# 	- Sample Date: 04-12-2013
#
# len_full_df = 992, count = 2
# 993/1000 Processing
# 	- Lat: -26.648056
# 	- Lon: 27.089444
# 	- Sample Date: 04-12-2013
#
# len_full_df = 993, count = 2
# 994/1000 Processing
# 	- Lat: -26.970278
# 	- Lon: 27.211111
# 	- Sample Date: 04-12-2013
#
# len_full_df = 994, count = 2
# 995/1000 Processing
# 	- Lat: -26.880278
# 	- Lon: 26.965
# 	- Sample Date: 04-12-2013
#
# len_full_df = 995, count = 2
# 996/1000 Processing
# 	- Lat: -26.98472222
# 	- Lon: 26.63227778
# 	- Sample Date: 04-12-2013
#
# len_full_df = 996, count = 2
# 997/1000 Processing
# 	- Lat: -31.000833
# 	- Lon: 26.353056
# 	- Sample Date: 04-12-2013
#
# len_full_df = 997, count = 2
# 998/1000 Processing
# 	- Lat: -30.679722
# 	- Lon: 26.7125
# 	- Sample Date: 04-12-2013
#
# len_full_df = 998, count = 2
# 999/1000 Processing
# 	- Lat: -28.1175
# 	- Lon: 26.719444
# 	- Sample Date: 06-08-2014
#
# len_full_df = 999, count = 2
# 1000/1000 Processing
# 	- Lat: -34.039722
# 	- Lon: 22.133333
# 	- Sample Date: 04-12-2013
#
# len_full_df = 1000, count = 2
# Verifying Data Frame # Rows: 1000

# %%
# session.sql(f"""
#     PUT file://{file_path}
#     'snow://workspace/USER$.PUBLIC."EY-AI-and-Data-Challenge-v2"/versions/live/'
#     AUTO_COMPRESS=FALSE
#     OVERWRITE=TRUE
# """).collect()
#
# print("File saved! Refresh the browser to see the files in the sidebar")
