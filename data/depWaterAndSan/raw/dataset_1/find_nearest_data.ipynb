# %%
import os

import numpy as np
import pandas as pd

from sklearn.metrics.pairwise import haversine_distances
from math import radians
from tqdm import tqdm

# %%
def make_dataframe_cols_lowercase(df):
    for col in df.columns:
        df.rename(columns={col: col.lower()}, inplace=True)

def add_formatted_join_column(df, join_col_name, drop_cols=None):
    df['sample date (date)'] = pd.to_datetime(df['sample date'], format='%d-%m-%Y')
    df['sample date'] = pd.to_datetime(df['sample date'], format='%d-%m-%Y').dt.strftime('%d-%m-%Y')
    df['latitude'] = df['latitude'].astype(float).round(6)
    df['longitude'] = df['longitude'].astype(float).round(6)
    df[join_col_name] = df['latitude'].astype(str) + "~" + df['longitude'].astype(str) + "~" + df['sample date']

    if drop_cols:
        df.drop(columns=drop_cols, inplace=True)

# %%
TRAIN_VAL_DATASET_PATH = "../../../submission_template.csv" # "../../../water_quality_training_dataset.csv"
TRAIN_OR_VAL_DESC = "training" if "water_quality_training_dataset" in TRAIN_VAL_DATASET_PATH else "validation"
DATE_PLUS_MINUS_DAYS = 30
RADIUS_DIST_KM = 100.0 # KMs
PRIMARY_COLUMNS = ['latitude', 'longitude', 'sample date']
DATA_COLUMNS = list({'ca_diss_water', 'ca_diss_water_dl', 'cl_diss_water',
       'cl_diss_water_dl', 'dms_tot_water', 'dms_tot_water_dl',
       'ec_phys_water', 'ec_phys_water_dl', 'f_diss_water', 'f_diss_water_dl',
       'kjel_n_tot_water', 'kjel_n_tot_water_dl', 'k_diss_water',
       'k_diss_water_dl', 'mg_diss_water', 'mg_diss_water_dl',
       'nh4_n_diss_water', 'nh4_n_diss_water_dl', 'no3_no2_n_calc_water_dl',
       'no3_no2_n_diss_water', 'no3_no2_n_diss_water_dl', 'na_diss_water',
       'na_diss_water_dl', 'po4_p_diss_water', 'po4_p_diss_water_dl',
       'p_tot_water', 'p_tot_water_dl', 'so4_diss_water',
       'so4_diss_water_dl', 'si_diss_water', 'si_diss_water_dl', 'tal_diss_water', 'tal_diss_water_dl',  'ph_diss_water', 'ph_diss_water_dl'})

# %%
wq_df = pd.read_csv(TRAIN_VAL_DATASET_PATH)
make_dataframe_cols_lowercase(wq_df)
add_formatted_join_column(wq_df, "join_column")
wq_df['sample date plus'] = wq_df['sample date (date)'] + pd.Timedelta(days=DATE_PLUS_MINUS_DAYS)
wq_df['sample date minus'] = wq_df['sample date (date)'] - pd.Timedelta(days=DATE_PLUS_MINUS_DAYS)

# %%
sa_wq_df = None
all_dfs = []
all_columns_set = set()

for region_name in os.listdir("extracted_data"):
    if not region_name.endswith(".csv"):
        print(region_name)
        for filename in os.listdir(f"extracted_data/{region_name}"):
            if filename.endswith(".csv"):
                print(f"\t\t{filename}")
                extracted_df = pd.read_csv(f"extracted_data/{region_name}/{filename}")
                all_columns_set.update(extracted_df.columns)
                all_dfs.append(extracted_df)
# Out:
# Breë
# 		bore.csv
# 		no_bore.csv
# Buffels et al
# 		bore.csv
# Bushmans et al
# 		bore.csv
# 		no_bore.csv
# Crocodile (E)
# 		bore.csv
# 		no_bore.csv
# Gamtoos
# 		bore.csv
# 		no_bore.csv
# Gourits
# 		bore.csv
# 		no_bore.csv
# Great Berg et al
# 		bore.csv
# 		no_bore.csv
# Great Fish
# 		bore.csv
# 		no_bore.csv
# Great Fish +
# Great Kei
# 		bore.csv
# 		no_bore.csv
# Keiskamma et al
# 		bore.csv
# 		no_bore.csv
# Kromme et al
# 		bore.csv
# 		no_bore.csv
# Limpopo
# 		bore.csv
# 		no_bore.csv
# Limpopo +
# Mzimvubu et al
# 		bore.csv
# 		no_bore.csv
# Olifants (E)
# 		bore.csv
# 		no_bore.csv
# Olifants (W) et al
# 		bore.csv
# 		no_bore.csv
# Orange
# 		bore.csv
# 		no_bore.csv
# Outside borders
# Phongolo et al
# 		bore.csv
# 		no_bore.csv
# Sundays
# 		bore.csv
# 		no_bore.csv
# Swartkops
# 		bore.csv
# 		no_bore.csv
# Thukela
# 		bore.csv
# 		no_bore.csv
# uMngeni et al
# 		bore.csv
# 		no_bore.csv
# Vaal
# 		bore.csv
# 		no_bore.csv

# %%
all_dfs[0]
# Out:
#     mon_feature_id            date_time sample_begin_depth  \
# 0        200189778  2015-03-31 12:45:00                  0
# 1        200189778  2015-09-23 11:55:00               #n/a
# 2        200189778  2016-04-13 14:00:00               #n/a
# 3        200189778  2016-09-16 13:01:00                  0
# 4        200189778  2017-04-25 13:56:00               #n/a
# 5        200189778  2017-10-20 11:20:00               #n/a
# 6        200189778  2021-10-19 13:14:00               #n/a
# 7        200189778  2022-10-18 13:54:00                  0
# 8        200189778  2023-05-09 13:26:00                  0
# 9        200189778  2023-05-09 13:26:00               #n/a
# 10       200189778  2023-11-20 15:05:00                  0
# 11       200189778  2024-04-25 08:28:00                  0
# 12       200189778  2024-04-25 08:28:00               #n/a
# 13       200189755  2012-08-27 14:10:00               #n/a
# 14       200189755  2013-04-11 10:48:00               #n/a
# 15       200189755  2014-03-13 12:00:00               #n/a
# 16       200189755  2014-09-23 11:13:00                  0
# 17       200189755  2015-03-31 09:35:00                  0
# 18       200189755  2015-09-23 09:10:00               #n/a
# 19       200189755  2016-04-13 10:20:00               #n/a
# 20       200189755  2016-09-16 09:26:00                  0
# 21       200189755  2017-04-25 10:38:00               #n/a
# 22       200189755  2017-10-20 08:48:00               #n/a
# 23       200189755  2021-10-19 09:40:00               #n/a
# 24       200189755  2022-10-18 09:37:00                  0
# 25       200189755  2023-05-09 09:47:00                  0
# 26       200189755  2023-05-09 09:47:00               #n/a
# 27       200189755  2024-04-25 11:24:00                  0
# 28       200189755  2024-04-25 11:24:00               #n/a
#
#         institution_abbr preservative_abbr Ca_Diss_Water Ca_Diss_Water_dl  \
# 0               DWS-RQIS             HGCL2         8.678              2.5
# 1               DWS-RQIS             HGCL2         9.122              2.5
# 2               DWS-RQIS             HGCL2           9.5              2.5
# 3               DWS-RQIS             HGCL2           8.5              2.5
# 4               DWS-RQIS             HGCL2           8.4              2.5
# 5               DWS-RQIS             HGCL2           9.4              2.5
# 6   WC-CSIR-STELLENBOSCH              NONE           8.5                1
# 7               DWS-RQIS              NONE         5.006             0.13
# 8               DWS-RQIS              NONE          #n/a             #n/a
# 9               DWS-RQIS              NONE          9.19                1
# 10            GP-INT LAB              NONE          5.07                2
# 11              DWS-RQIS              NONE          #n/a             #n/a
# 12              DWS-RQIS              NONE         9.247                1
# 13              DWS-RQIS             HGCL2         1.989                1
# 14              DWS-RQIS             HGCL2         3.304                1
# 15              DWS-RQIS              NONE          1.25              2.5
# 16              DWS-RQIS             HGCL2          1.25              2.5
# 17              DWS-RQIS             HGCL2          1.25              2.5
# 18              DWS-RQIS             HGCL2          1.25              2.5
# 19              DWS-RQIS             HGCL2          1.25              2.5
# 20              DWS-RQIS             HGCL2           8.1              2.5
# 21              DWS-RQIS             HGCL2           2.5                2
# 22              DWS-RQIS             HGCL2           0.8              0.7
# 23  WC-CSIR-STELLENBOSCH              NONE           1.3                1
# 24              DWS-RQIS              NONE           0.5                1
# 25              DWS-RQIS              NONE          #n/a             #n/a
# 26              DWS-RQIS              NONE          #n/a             #n/a
# 27              DWS-RQIS              NONE          #n/a             #n/a
# 28              DWS-RQIS              NONE           0.5                1
#
#    Cl_Diss_Water Cl_Diss_Water_dl DMS_Tot_Water  ...  \
# 0         18.699                1        69.383  ...
# 1         14.544                2        54.177  ...
# 2           16.6                2        63.972  ...
# 3           15.3                2        62.987  ...
# 4           17.1                2        70.522  ...
# 5           20.4                2        81.129  ...
# 6             17                2        63.299  ...
# 7         17.384                3        53.162  ...
# 8         18.724                3        64.085  ...
# 9           #n/a             #n/a          #n/a  ...
# 10          15.9             3.58          #n/a  ...
# 11        16.801                3        71.977  ...
# 12          #n/a             #n/a          #n/a  ...
# 13        19.915                1        47.285  ...
# 14        18.875                1        61.702  ...
# 15        18.324                1          #n/a  ...
# 16        19.846                2          #n/a  ...
# 17        19.523                1        51.396  ...
# 18        18.939                2        46.536  ...
# 19          20.4                2        47.826  ...
# 20          38.1                2       120.035  ...
# 21          21.9                2        80.071  ...
# 22          24.2                1        61.219  ...
# 23            20                2        54.237  ...
# 24        24.537                3        58.166  ...
# 25        27.094                3          #n/a  ...
# 26          #n/a             #n/a          #n/a  ...
# 27        27.319                3        49.101  ...
# 28          #n/a             #n/a          #n/a  ...
#
#                                             data_desc data_num_records  \
# 0     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 1     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 2     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 3     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 4     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 5     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 6     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 7     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 8     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 9     Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 10    Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 11    Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 12    Goudini Spa Replacement Borehole BE00120 (N_GW)                6
# 13  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 14  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 15  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 16  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 17  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 18  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 19  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 20  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 21  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 22  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 23  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 24  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 25  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 26  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 27  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
# 28  Rheboks Vlakte ptn Heinzberg(Koo Valley) Koo 0...               10
#
#    data_first_date data_last_date data_med_ec  data_flow  data_lat  data_lng  \
# 0       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 1       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 2       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 3       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 4       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 5       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 6       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 7       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 8       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 9       2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 10      2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 11      2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 12      2015-03-31     2017-10-20          11  200189778 -33.66944  19.26533
# 13      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 14      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 15      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 16      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 17      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 18      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 19      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 20      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 21      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 22      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 23      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 24      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 25      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 26      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 27      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
# 28      2012-08-27     2017-10-20          10         73 -33.62981  19.76077
#
#    region_name bore_type
# 0         Breë      bore
# 1         Breë      bore
# 2         Breë      bore
# 3         Breë      bore
# 4         Breë      bore
# 5         Breë      bore
# 6         Breë      bore
# 7         Breë      bore
# 8         Breë      bore
# 9         Breë      bore
# 10        Breë      bore
# 11        Breë      bore
# 12        Breë      bore
# 13        Breë      bore
# 14        Breë      bore
# 15        Breë      bore
# 16        Breë      bore
# 17        Breë      bore
# 18        Breë      bore
# 19        Breë      bore
# 20        Breë      bore
# 21        Breë      bore
# 22        Breë      bore
# 23        Breë      bore
# 24        Breë      bore
# 25        Breë      bore
# 26        Breë      bore
# 27        Breë      bore
# 28        Breë      bore
#
# [29 rows x 54 columns]

# %%
sa_wq_df = pd.DataFrame(columns=list(sorted(all_columns_set)))
for df in all_dfs:
    sa_wq_df_pre = pd.DataFrame(columns=list(sorted(all_columns_set)))

    for col in list(sa_wq_df_pre.columns):
        if col in list(df.columns):
            sa_wq_df_pre[col] = df[col]

    sa_wq_df = pd.concat([sa_wq_df, sa_wq_df_pre], axis=0, ignore_index=True)
    print(f"Length of sa_wq_df: {len(sa_wq_df)}")
# Out:
# Length of sa_wq_df: 29
# Length of sa_wq_df: 13294
# Length of sa_wq_df: 13332
# Length of sa_wq_df: 13337
# Length of sa_wq_df: 13539
# Length of sa_wq_df: 13578
# Length of sa_wq_df: 25967
# Length of sa_wq_df: 26130
# Length of sa_wq_df: 30144
# Length of sa_wq_df: 30178
# Length of sa_wq_df: 34287
# Length of sa_wq_df: 35169
# Length of sa_wq_df: 80878
# Length of sa_wq_df: 80966
# Length of sa_wq_df: 83226
# Length of sa_wq_df: 83407
# Length of sa_wq_df: 85099
# Length of sa_wq_df: 85136
# Length of sa_wq_df: 85666
# Length of sa_wq_df: 85675
# Length of sa_wq_df: 91157
# Length of sa_wq_df: 92628
# Length of sa_wq_df: 105786
# Length of sa_wq_df: 106002
# Length of sa_wq_df: 111963
# Length of sa_wq_df: 112611
# Length of sa_wq_df: 122268
# Length of sa_wq_df: 122667
# Length of sa_wq_df: 126951
# Length of sa_wq_df: 128037
# Length of sa_wq_df: 135799
# Length of sa_wq_df: 135857
# Length of sa_wq_df: 148077
# Length of sa_wq_df: 148149
# Length of sa_wq_df: 149101
# Length of sa_wq_df: 149110
# Length of sa_wq_df: 149735
# Length of sa_wq_df: 150433
# Length of sa_wq_df: 156152
# Length of sa_wq_df: 156153
# Length of sa_wq_df: 160977
# Length of sa_wq_df: 162156
# Length of sa_wq_df: 190709

# %%
make_dataframe_cols_lowercase(sa_wq_df)
sa_wq_df["year"] = sa_wq_df["date_time"].str.split("-").str[0]
sa_wq_df["month"] = sa_wq_df["date_time"].str.split("-").str[1]
sa_wq_df["day"] = sa_wq_df["date_time"].str.split("-").str[2]
sa_wq_df["day"] = sa_wq_df["day"].str.split(" ").str[0]
sa_wq_df["date"] = sa_wq_df["year"] + "-" + sa_wq_df["month"] + "-" + sa_wq_df["day"]
sa_wq_df["sample date"] = pd.to_datetime(sa_wq_df["date"], format='%Y-%m-%d').dt.strftime('%d-%m-%Y')
sa_wq_df = sa_wq_df.rename(columns={'data_lat': 'latitude', 'data_lng': 'longitude'})
add_formatted_join_column(sa_wq_df, "join_column")
sa_wq_df.replace('#n/a', np.nan, inplace=True)

for col in DATA_COLUMNS:
    sa_wq_df[col] = sa_wq_df[col].astype(float)

# %%
sa_wq_df.to_csv("extracted_data/extracted_depWatSanData.csv", index=False)

# %%
ordered_cols = PRIMARY_COLUMNS
ordered_cols.extend(DATA_COLUMNS)
df_all_rows = None

for index, wq_row in tqdm(wq_df.iterrows(), desc="Process Water Quality Data"):
    lat = wq_row["latitude"]
    lon = wq_row["longitude"]
    sample_date = wq_row["sample date"]
    sample_date_plus = wq_row["sample date plus"]
    sample_date_minus = wq_row["sample date minus"]

    sa_wq_df_filter = sa_wq_df[(sample_date_minus <= sa_wq_df["sample date (date)"]) & (sa_wq_df["sample date (date)"] <= sample_date_plus)]
    if sa_wq_df_filter.shape[0] == 0:
        continue
    sa_wq_df_filter['euc_dist_dec_deg'] = np.sqrt((sa_wq_df_filter['latitude'] - lat)**2 + (sa_wq_df_filter['longitude'] - lon)**2)
    sa_wq_df_filter = sa_wq_df_filter.sort_values(by='euc_dist_dec_deg')
    sa_wq_df_filter['latitude_rad'] = np.radians(sa_wq_df_filter['latitude'])
    sa_wq_df_filter['longitude_rad'] = np.radians(sa_wq_df_filter['longitude'])

    ref_point_rad = [radians(lat), radians(lon)]

    sa_wq_df_filter['euc_dist_km'] = haversine_distances(sa_wq_df_filter[['latitude_rad', 'longitude_rad']], [ref_point_rad]) * 6371
    sa_wq_df_filter = sa_wq_df_filter.sort_values(by='euc_dist_km')
    sa_wq_df_filter = sa_wq_df_filter[sa_wq_df_filter['euc_dist_km'] < RADIUS_DIST_KM]

    sa_wq_df_filter = sa_wq_df_filter[DATA_COLUMNS]
    sa_wq_df_filter = sa_wq_df_filter.mean()

    sa_wq_df_filter['latitude'] = lat
    sa_wq_df_filter['longitude'] = lon
    sa_wq_df_filter['sample date'] = sample_date

    sa_wq_df_filter = sa_wq_df_filter[ordered_cols]

    if df_all_rows is None:
        df_all_rows = sa_wq_df_filter.to_frame().T
    else:
        df_all_rows = pd.concat([df_all_rows, sa_wq_df_filter.to_frame().T], axis=0, ignore_index=True)
# Out:
# Process Water Quality Data: 200it [00:01, 113.24it/s]

# %%
df_all_rows_process = df_all_rows.copy()

# %%
df_all_rows_process
# Out:
#       latitude  longitude sample date po4_p_diss_water f_diss_water  \
# 0   -32.043333  27.822778  01-09-2014         0.016667       0.1825
# 1   -33.329167    26.0775  16-09-2015             0.01         1.23
# 2   -32.991639  27.640028  07-05-2015         5.801667          NaN
# 3   -34.096389  24.439167  07-02-2012         1.437588     0.152167
# 4   -32.000556  28.581667  01-10-2014            0.059       0.1825
# ..         ...        ...         ...              ...          ...
# 195 -33.771111  25.386667  06-12-2012         0.271273         0.14
# 196 -33.185361   27.39075  04-09-2014             0.05          NaN
# 197 -32.043333  27.822778  28-09-2015          4.16625     0.253333
# 198 -33.001667  25.161389  08-01-2015          0.49875     0.278571
# 199  -33.23778   26.99472  27-03-2013         1.136929          NaN
#
#     na_diss_water tal_diss_water_dl mg_diss_water nh4_n_diss_water  \
# 0             NaN              10.0         3.999         0.048333
# 1          742.26              10.0       153.798            2.535
# 2             NaN               NaN           NaN        31.816667
# 3       43.042333               5.0      7.117167         2.718235
# 4             NaN              10.0         4.042         0.257143
# ..            ...               ...           ...              ...
# 195      106.7544               5.0       15.7428         1.266818
# 196           NaN               NaN           NaN             0.04
# 197        6.7935              10.0      4.022333         2.420667
# 198      24.46275              10.0     32.077286         0.114375
# 199           NaN               NaN           NaN             2.28
#
#     p_tot_water_dl  ... so4_diss_water_dl no3_no2_n_diss_water_dl  \
# 0             0.02  ...              1.56                   0.085
# 1              NaN  ...               1.2                   0.055
# 2              NaN  ...               NaN                    0.01
# 3              NaN  ...               3.0                0.075294
# 4             0.02  ...               1.2                0.061429
# ..             ...  ...               ...                     ...
# 195            NaN  ...               3.0                0.028182
# 196            NaN  ...               NaN                    0.01
# 197           0.02  ...               3.0                0.030769
# 198            NaN  ...          1.971429                 0.08875
# 199            NaN  ...               NaN                0.032308
#
#     si_diss_water ca_diss_water kjel_n_tot_water tal_diss_water  \
# 0          7.0512        8.3508            0.562        43.1086
# 1          10.561        166.64              NaN          478.6
# 2             NaN           NaN              NaN            NaN
# 3        3.189833        9.2402              NaN         28.431
# 4         7.14725         8.009            0.562         41.691
# ..            ...           ...              ...            ...
# 195        2.9202       17.7976              NaN        53.4804
# 196           NaN           NaN              NaN            NaN
# 197         6.772      7.851333            0.645      38.119333
# 198      1.743714     22.988833              NaN      44.168167
# 199           NaN           NaN              NaN            NaN
#
#     no3_no2_n_diss_water ec_phys_water cl_diss_water_dl na_diss_water_dl
# 0               0.282167     19.068333              1.8              NaN
# 1                12.4495         299.0              2.0              1.6
# 2               1.106667    122.333333              NaN              NaN
# 3               0.970412     93.315882         0.393333              4.0
# 4               1.603429     40.494444              2.0              NaN
# ..                   ...           ...              ...              ...
# 195             1.130273    229.845455              1.0              4.0
# 196                0.055          87.5              NaN              NaN
# 197                0.774     84.685385              1.0              4.0
# 198             0.297625      93.69375         1.428571              3.0
# 199             1.631538       207.625              NaN              NaN
#
# [200 rows x 38 columns]

# %%
if TRAIN_OR_VAL_DESC == "training":
    num_rows = df_all_rows_process.shape[0]
    for col in DATA_COLUMNS:
        num_na = df_all_rows_process[col].isna().sum()
        perc_null = num_na / num_rows * 100
        print(f"{col} - {perc_null}%")
        if perc_null > 20:
            print(f"\t Dropping column")
            df_all_rows_process.drop(columns=col, inplace=True)
elif TRAIN_OR_VAL_DESC == "validation":
    df_train = pd.read_csv("../../depWaterAndSan_features_training_chemReadings.csv")
    df_all_rows_process = df_all_rows_process[df_train.columns]

# %%
df_all_rows_process.columns
# Out:
# Index(['latitude', 'longitude', 'sample date', 'mg_diss_water_dl',
#        'cl_diss_water_dl', 'ca_diss_water_dl', 'no3_no2_n_diss_water_dl',
#        'cl_diss_water', 'ec_phys_water', 'ph_diss_water_dl',
#        'no3_no2_n_diss_water', 'nh4_n_diss_water_dl', 'na_diss_water_dl',
#        'tal_diss_water', 'ph_diss_water', 'na_diss_water', 'po4_p_diss_water',
#        'mg_diss_water', 'nh4_n_diss_water', 'so4_diss_water',
#        'f_diss_water_dl', 'ca_diss_water', 'ec_phys_water_dl', 'f_diss_water',
#        'po4_p_diss_water_dl', 'tal_diss_water_dl', 'so4_diss_water_dl'],
#       dtype='str')

# %%
df_all_rows_process.to_csv(f"../../depWaterAndSan_features_{TRAIN_OR_VAL_DESC}_chemReadings.csv", index=False)
